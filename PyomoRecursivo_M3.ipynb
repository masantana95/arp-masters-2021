# %% [markdown]
# # Importação

# %%
import pandas as pd
import pyomo.environ as pyo 
from pyomo.environ import SolverFactory
from pyomo.environ import Var, Integers, Binary, Constraint,TransformationFactory,RangeSet
from datetime import time, datetime
#import highspy
#import gurobipy

# Timestamp da rodada
P_HoraDaRodada = datetime.now()
P_HoraDaRodadaTimeStamp = int(P_HoraDaRodada.strftime("%Y%m%d%H%M%S"))

# Inicialização do modelo
model = pyo.ConcreteModel()
solver_selecionado = 'cbc'
relaxacao_linear = 0 # 0 = MIP, 1 = Relaxação linear

# importação de libs específicas de acordo com o solver
#if solver_selecionado == 'highs':
    #import highspy
#if solver_selecionado == 'gurobi':
    #import gurobipy
if solver_selecionado == 'mosek':
    import mosek

# Inicialização de dicionários
Ps_NomeDaRodada = {}
P_SOL_incumbent_solution = {}
P_SOL_solver_status = {}
P_SOL_solver_time = {}
P_SOL_best_bound = {}
P_SOL_optimality_gap = {}
start_time = {}
end_time = {}
elapsed_time = {}
P_total_variables = {}
P_integer_variables = {}
P_binary_variables = {}
P_total_constraints = {}

# Funções de apoio
def Func_ConversaoDatetimeParaMinutosEscalares(P_ARG_Datetime):
    P_Minutos = P_ARG_Datetime.hour * 60 + P_ARG_Datetime.minute
    return P_Minutos

def Func_ConversaoDatetimeParaMinutosParametros(data_dict):
    return {
        key: (val.hour * 60 + val.minute if isinstance(val, time) else val)
        for key, val in data_dict.items()
    }

# %% [markdown]
# # Recursão

# %%
S_Instancias = ["i09","i10","i10C","i11","i12","i13","i14C","i15","i25","i30","i37","i38","i45","i46C","i50"]
S_InstanciasMuitoPequenas = ["i09","i10","i10C","i11"]
S_InstanciasPequenas = ["i09","i10","i10C","i11","i12","i13"]
S_InstanciasGrandes = ["i25","i30","i37","i38","i45","i46C","i50"]
S_InstanciasRodada = ["i25","i30","i37","i38"]
S_Teste =  ["i09"]

## Início da recursão #####################################################################################################################
for instancia in S_Teste:
    
    # IMPORTAÇÃO ###############################################################################################################################3
    
    #1 Leitura do arquivo .xslx para conjuntos e parâmetros
    Ps_CaminhoDaPlanilha = f"G:\Meu Drive\Planilhas para Estudos\{instancia}.xlsx"
    #1.1 Escalares
    df_escalares = pd.read_excel(Ps_CaminhoDaPlanilha, sheet_name = "Escalares")
    #print(df_escalares)
    #print(df_escalares.dtypes)

    #1.2 Programacao Inicial
    df_proginicial = pd.read_excel(Ps_CaminhoDaPlanilha, sheet_name = "ProgramacaoInicial")
    #print(df_proginicial)
    #print(df_proginicial.dtypes)

    #1.3 Aeronaves
    df_aeronaves = pd.read_excel(Ps_CaminhoDaPlanilha, sheet_name = "Aeronaves")
    #print(df_aeronaves)
    #print(df_aeronaves.dtypes)

    #1.1 Compatibilidade
    df_compatibilidade = pd.read_excel(Ps_CaminhoDaPlanilha, sheet_name = "Compatibilidade")
    #print(df_compatibilidade)
    #print(df_compatibilidade.dtypes)

    ########################################################## Conjuntos
    # 2 Criação de conjuntos e parametros
    # 2.1 Conjuntos

    #Voos
    # Todos
    model.S_VoosReais = pyo.Set(initialize=df_proginicial.Voo)
    S_VoosReais = model.S_VoosReais
    #print(list(S_VoosReais))
    # Comitiva
    model.S_VoosComitiva = pyo.Set(
        within=model.S_VoosReais, 
        initialize=df_proginicial[df_proginicial['TipoDoVoo'] == "Tab.Comitivas"]['Voo'].tolist()
    )
    S_VoosComitiva = model.S_VoosComitiva
    # Transferência 2
    model.S_VoosT2 = pyo.Set(
        within=model.S_VoosReais, 
        initialize=df_proginicial[df_proginicial['TipoDoVoo'] == "Transf.2"]['Voo'].tolist()
    )
    S_VoosT2 = model.S_VoosT2
    # Transferência 1
    model.S_VoosT1 = pyo.Set(
        within=model.S_VoosReais, 
        initialize=df_proginicial[df_proginicial['TipoDoVoo'] == "Transf.1"]['Voo'].tolist()
    )
    S_VoosT1 = model.S_VoosT1
    # Transferência todos
    S_VoosTransferencia = S_VoosT1.union(S_VoosT2)
    # Tabela
    model.S_VoosTabela = pyo.Set(
        within=model.S_VoosReais, 
        initialize=df_proginicial[df_proginicial['TipoDoVoo'] == "Tab."]['Voo'].tolist()
    )
    S_VoosTabela = model.S_VoosTabela
    # Tabela + Comitiva
    S_VoosTabelaComitivaLista = S_VoosTabela.union(S_VoosComitiva)
    model.S_VoosTabelaComitiva = pyo.Set(
        initialize=S_VoosTabelaComitivaLista
    )
    S_VoosTabelaComitiva = model.S_VoosTabelaComitiva
    print(list(S_VoosTabelaComitiva))

    # Outros subconjuntos de voos usados no modelo
    # Reais exceto voos comitiva
    S_VoosReaisSemComitiva= S_VoosReais - S_VoosComitiva
    #print("S_VoosReaisSemComitiva=", list(S_VoosReaisSemComitiva))

    #Unidades Marítimas
    model.S_UM = pyo.Set(initialize=df_proginicial.UMDestino)
    S_UM = model.S_UM

    #Aeronaves
    #Geral
    model.S_Aeronaves = pyo.Set(initialize=df_aeronaves.Aeronave)
    S_Aeronaves = model.S_Aeronaves 
    # Spot
    model.S_AeronavesSpot= pyo.Set(
        within=model.S_Aeronaves, 
        initialize=df_aeronaves[df_aeronaves['TipoDaAeronave'] == 3]['Aeronave'].tolist()
    )
    S_AeronavesSpot = model.S_AeronavesSpot
    # Pool
    model.S_AeronavesPool= pyo.Set(
        within=model.S_Aeronaves, 
        initialize=df_aeronaves[df_aeronaves['TipoDaAeronave'] == 2]['Aeronave'].tolist()
    )
    S_AeronavesPool = model.S_AeronavesPool
    # Comum
    model.S_AeronavesComum= pyo.Set(
        within=model.S_Aeronaves, 
        initialize=df_aeronaves[df_aeronaves['TipoDaAeronave'] == 1]['Aeronave'].tolist()
    )
    S_AeronavesComum = model.S_AeronavesComum

    ##### Parâmetros
    #2.2.1 Escalares usando param
    Ps_NomeDaInstancia = df_escalares.NomeDaInstancia[0]  
    print("Ps_NomeDaInstancia = ",Ps_NomeDaInstancia)

    P_NumeroDeVoos= df_escalares.NumeroDeVoos[0]
    #print("P_NumeroDeVoos = ",P_NumeroDeVoos)

    P_TempoDeSeguranca = df_escalares.TempoDeSeguranca[0]
    #print("P_TempoDeSeguranca = ",P_TempoDeSeguranca)

    P_NumeroMaxDeVoosPorAeronave = df_escalares.NumeroMaxDeVoosPorAeronave[0]
    #print("P_NumeroMaxDeVoosPorAeronave = ",P_NumeroMaxDeVoosPorAeronave)
    
    ######################################################################
    # Importação do conjunto de Posições, que é dependente do parâmetro a seguir
    S_PosicoesLista = list(range(1, P_NumeroMaxDeVoosPorAeronave+1))
    #print("S_PosicoesLista = ", S_PosicoesLista)

    model.S_Posicoes = pyo.Set(initialize=S_PosicoesLista)
    S_Posicoes = model.S_Posicoes
    print("S_Posicoes = ", list(S_Posicoes))
    model.S_PosicoesExcetoUltima = pyo.Set(initialize=S_PosicoesLista[:-1])
    S_PosicoesExcetoUltima = model.S_PosicoesExcetoUltima
    print("S_PosicoesExcetoUltima = ", list(S_PosicoesExcetoUltima))
    ######################################################################

    P_TurnaroundTime = df_escalares.TurnaroundTime[0]
    #print("P_TurnaroundTime = ",P_TurnaroundTime)

    P_AtrasoLimite1 = df_escalares.AtrasoLimite1[0]  
    #print("P_AtrasoLimite1 = ",P_AtrasoLimite1)

    P_AtrasoLimite2 = df_escalares.AtrasoLimite2[0]  
    #print("P_AtrasoLimite2 = ",P_AtrasoLimite2)

    P_InicioDoHorizonteDatetime = df_escalares.InicioDoHorizonte[0]
    #print("P_InicioDoHorizonteDatetime = ",P_InicioDoHorizonteDatetime)
    P_InicioDoHorizonte = Func_ConversaoDatetimeParaMinutosEscalares(P_InicioDoHorizonteDatetime)
    #print("P_InicioDoHorizonte = ",P_InicioDoHorizonte)

    P_FimDoHorizonteDatetime = df_escalares.FimDoHorizonte[0]
    #print("P_FimDoHorizonteDatetime = ",P_FimDoHorizonteDatetime)
    P_FimDoHorizonte = Func_ConversaoDatetimeParaMinutosEscalares(P_FimDoHorizonteDatetime)
    #print("P_FimDoHorizonte = ",P_FimDoHorizonte)

    P_PenCancelamentoComitiva = df_escalares.PenCancelamentoComitiva[0] 
    #print("P_PenCancelamentoComitiva = ",P_PenCancelamentoComitiva.value)

    P_PenCancelamento2Dias = df_escalares.PenCancelamento2Dias[0]
    #print("P_PenCancelamento2Dias = ",P_PenCancelamento2Dias.value)

    P_PenCancelamento1Dia = df_escalares.PenCancelamento1Dia[0]
    #print("P_PenCancelamento1Dia = ",P_PenCancelamento1Dia.value)

    P_PenCancelamentoTabela = df_escalares.PenCancelamentoTabela[0] 
    #print("P_PenCancelamentoTabela = ",P_PenCancelamentoTabela.value)

    P_PenUsoAeronaveSpot = df_escalares.PenUsoAeronaveSpot[0]
    #print("P_PenUsoAeronaveSpot = ",P_PenUsoAeronaveSpot.value)

    P_PenUsoAeronavePool = df_escalares.PenUsoAeronavePool[0]
    #print("P_PenUsoAeronavePool = ",P_PenUsoAeronavePool.value)

    P_PenUsoAeronaveComum = df_escalares.PenUsoAeronaveComum[0] 
    #print("P_PenUsoAeronaveComum = ",P_PenUsoAeronaveComum.value)

    P_PenTrocaAeronave = df_escalares.PenTrocaAeronave[0] 
    #print("P_PenTrocaAeronave = ",P_PenTrocaAeronave.value)

    P_PenAtrasoTipo2 = df_escalares.PenAtrasoTipo2[0]
    #print("P_PenAtrasoTipo2 = ",P_PenAtrasoTipo2.value)

    P_PenAtrasoTipo1 = df_escalares.PenAtrasoTipo1[0]
    #print("P_PenAtrasoTipo1 = ",P_PenAtrasoTipo1.value)

    P_PenAtrasoMinuto = df_escalares.PenAtrasoMinuto[0]
    #print("P_PenAtrasoMinuto = ",P_PenAtrasoMinuto.value)

    #2.2.2 Indexados
    #Convertendo para um dicionário, mas o índice deve ser igual ao nome da coluna
    #Horário Inicial
    #   Conversao de datetime para minutos
    P_HorarioInicialDatetime_dict = df_proginicial.set_index('Voo')['HorarioInicial'].to_dict()
    P_HorarioInicial_dict = Func_ConversaoDatetimeParaMinutosParametros(P_HorarioInicialDatetime_dict)
    #   Alteração do horário inicial para ser sempre 07:00
    for voo in S_VoosReais:
        if P_HorarioInicial_dict[voo] < 420:
            P_HorarioInicial_dict[voo] = 420

    #   Transformação de lista em parâmetro para modelo
    model.P_HorarioInicial = pyo.Param(S_VoosReais, initialize=P_HorarioInicial_dict)
    P_HorarioInicial = model.P_HorarioInicial
    #print("P_HorarioInicial = ",P_HorarioInicial.display())

    #UM Destino
    P_UMDestino_dict = df_proginicial.set_index('Voo')['UMDestino'].to_dict()
    model.P_UMDestino = pyo.Param(S_VoosReais, initialize=P_UMDestino_dict)
    P_UMDestino = model.P_UMDestino  
    #print("P_UMDestino = ",P_UMDestino.display())

    #Duração do Voo
    #   Conversao de datetime para minutos
    P_DuracaoDoVooDatetime_dict = df_proginicial.set_index('Voo')['DuracaoDoVoo'].to_dict()
    P_DuracaoDoVoo_dict = Func_ConversaoDatetimeParaMinutosParametros(P_DuracaoDoVooDatetime_dict)
    #   Transformação de lista em parâmetro para modelo
    model.P_DuracaoDoVoo = pyo.Param(S_VoosReais, initialize=P_DuracaoDoVoo_dict)
    P_DuracaoDoVoo = model.P_DuracaoDoVoo  
    print("P_DuracaoDoVoo= ",P_DuracaoDoVoo.display())

    # Aeronave inicial
    P_AeronaveInicialString_dict = df_proginicial.set_index('Voo')['AeronaveInicial'].to_dict()
    # Convertendo para um parâmetro de 2 índices binário, em formato de dicionário
    P_AeronaveInicial = {}
    for i in S_VoosReais:
        for h in S_Aeronaves:
            if P_AeronaveInicialString_dict[i] == h:
                P_AeronaveInicial[i,h] = 1
            else:
                P_AeronaveInicial[i,h] = 0

    # Declarando o dicionário como parâmetro         
    model.P_AeronaveInicial = pyo.Param(S_VoosReais, S_Aeronaves, initialize=P_AeronaveInicial)
    P_AeronaveInicial = model.P_AeronaveInicial
    #print("P_AeronaveInicial = ",P_AeronaveInicial.display())

    # Tempo de Permanência
    #   Conversao de datetime para minutos
    P_TempoDePermanenciaDatetime_dict = df_proginicial.set_index('Voo')['TempoDePermanencia'].to_dict()
    P_TempoDePermanencia_dict = Func_ConversaoDatetimeParaMinutosParametros(P_TempoDePermanenciaDatetime_dict)
    #   Transformação de lista em parâmetro para modelo
    model.P_TempoDePermanencia = pyo.Param(S_VoosReais, initialize=P_TempoDePermanencia_dict)
    P_TempoDePermanencia = model.P_TempoDePermanencia 
    #print("P_TempoDePermanencia = ",P_TempoDePermanencia.display())

    # Tipo de Aeronave
    P_TipoDeAeronave_dict = df_aeronaves.set_index('Aeronave')['TipoDaAeronave'].to_dict()
    model.P_TipoDeAeronave = pyo.Param(S_Aeronaves, initialize=P_TipoDeAeronave_dict)
    P_TipoDeAeronave = model.P_TipoDeAeronave 
    #print("P_TipoDeAeronave = ",P_TipoDeAeronave.display())

    # Compatibilidade
    # Como esse parâmetro possui mais de um índice, é necessária uma manipulação prévia
    # Além disso, o dataframe com os dados deste parâmetro está num formato em que um dos indices (S_Voos) está na coluna e o outro (S_Aeronaves) está como cabeçalho
    # Para isso, os passos abaixo são seguidos:
    # Passo 1) usar a função .melt para alterar o formato do dataframe, transferindo o cabeçalho para uma nova coluna:
    df_compatibilidade_mod= df_compatibilidade.melt(id_vars=['Voo'], var_name='Aeronaves', value_name='Compatibilidade')
    # Passo 2) Create the dictionary in the (S_VoosReais, S_UM): Value format, que é o formato que a função pyo.Param aceita os dados de um parâmetro multiíndice
    P_Compatibilidade_dict = {(row['Voo'], row['Aeronaves']): row['Compatibilidade'] for _, row in df_compatibilidade_mod.iterrows()}
    # Passo 3) Por fim, realizar a atribuição ao parâmetro normalmente
    model.P_Compatibilidade = pyo.Param(S_VoosReais, S_Aeronaves, initialize=P_Compatibilidade_dict)
    P_Compatibilidade = model.P_Compatibilidade 
    # print("P_Compatibilidade = ",P_Compatibilidade.display())

    #2.2.1 Escalares usando param
    Ps_NomeDaInstancia = df_escalares.NomeDaInstancia[0]  
    print("Ps_NomeDaInstancia = ",Ps_NomeDaInstancia)

    P_NumeroDeVoos= df_escalares.NumeroDeVoos[0]
    #print("P_NumeroDeVoos = ",P_NumeroDeVoos)

    P_TempoDeSeguranca = df_escalares.TempoDeSeguranca[0]
    #print("P_TempoDeSeguranca = ",P_TempoDeSeguranca)

    P_NumeroMaxDeVoosPorAeronave = df_escalares.NumeroMaxDeVoosPorAeronave[0]
    #print("P_NumeroMaxDeVoosPorAeronave = ",P_NumeroMaxDeVoosPorAeronave)

    P_TurnaroundTime = df_escalares.TurnaroundTime[0]
    #print("P_TurnaroundTime = ",P_TurnaroundTime)

    P_AtrasoLimite1 = df_escalares.AtrasoLimite1[0]  
    #print("P_AtrasoLimite1 = ",P_AtrasoLimite1)

    P_AtrasoLimite2 = df_escalares.AtrasoLimite2[0]  
    #print("P_AtrasoLimite2 = ",P_AtrasoLimite2)

    P_InicioDoHorizonteDatetime = df_escalares.InicioDoHorizonte[0]
    #print("P_InicioDoHorizonteDatetime = ",P_InicioDoHorizonteDatetime)
    P_InicioDoHorizonte = Func_ConversaoDatetimeParaMinutosEscalares(P_InicioDoHorizonteDatetime)
    #print("P_InicioDoHorizonte = ",P_InicioDoHorizonte)

    P_FimDoHorizonteDatetime = df_escalares.FimDoHorizonte[0]
    #print("P_FimDoHorizonteDatetime = ",P_FimDoHorizonteDatetime)
    P_FimDoHorizonte = Func_ConversaoDatetimeParaMinutosEscalares(P_FimDoHorizonteDatetime)
    #print("P_FimDoHorizonte = ",P_FimDoHorizonte)

    P_PenCancelamentoComitiva = df_escalares.PenCancelamentoComitiva[0] 
    #print("P_PenCancelamentoComitiva = ",P_PenCancelamentoComitiva.value)

    P_PenCancelamento2Dias = df_escalares.PenCancelamento2Dias[0]
    #print("P_PenCancelamento2Dias = ",P_PenCancelamento2Dias.value)

    P_PenCancelamento1Dia = df_escalares.PenCancelamento1Dia[0]
    #print("P_PenCancelamento1Dia = ",P_PenCancelamento1Dia.value)

    P_PenCancelamentoTabela = df_escalares.PenCancelamentoTabela[0] 
    #print("P_PenCancelamentoTabela = ",P_PenCancelamentoTabela.value)

    P_PenUsoAeronaveSpot = df_escalares.PenUsoAeronaveSpot[0]
    #print("P_PenUsoAeronaveSpot = ",P_PenUsoAeronaveSpot.value)

    P_PenUsoAeronavePool = df_escalares.PenUsoAeronavePool[0]
    #print("P_PenUsoAeronavePool = ",P_PenUsoAeronavePool.value)

    P_PenUsoAeronaveComum = df_escalares.PenUsoAeronaveComum[0] 
    #print("P_PenUsoAeronaveComum = ",P_PenUsoAeronaveComum.value)

    P_PenTrocaAeronave = df_escalares.PenTrocaAeronave[0] 
    #print("P_PenTrocaAeronave = ",P_PenTrocaAeronave.value)

    P_PenAtrasoTipo2 = df_escalares.PenAtrasoTipo2[0]
    #print("P_PenAtrasoTipo2 = ",P_PenAtrasoTipo2.value)

    P_PenAtrasoTipo1 = df_escalares.PenAtrasoTipo1[0]
    #print("P_PenAtrasoTipo1 = ",P_PenAtrasoTipo1.value)

    P_PenAtrasoMinuto = df_escalares.PenAtrasoMinuto[0]
    #print("P_PenAtrasoMinuto = ",P_PenAtrasoMinuto.value)

    #2.2.2 Indexados
    #Convertendo para um dicionário, mas o índice deve ser igual ao nome da coluna
    #Horário Inicial
    #   Conversao de datetime para minutos
    P_HorarioInicialDatetime_dict = df_proginicial.set_index('Voo')['HorarioInicial'].to_dict()
    P_HorarioInicial_dict = Func_ConversaoDatetimeParaMinutosParametros(P_HorarioInicialDatetime_dict)
    #   Alteração do horário inicial para ser sempre 07:00
    for voo in S_VoosReais:
        if P_HorarioInicial_dict[voo] < 420:
            P_HorarioInicial_dict[voo] = 420

    #   Transformação de lista em parâmetro para modelo
    model.P_HorarioInicial = pyo.Param(S_VoosReais, initialize=P_HorarioInicial_dict)
    P_HorarioInicial = model.P_HorarioInicial
    #print("P_HorarioInicial = ",P_HorarioInicial.display())

    #UM Destino
    P_UMDestino_dict = df_proginicial.set_index('Voo')['UMDestino'].to_dict()
    model.P_UMDestino = pyo.Param(S_VoosReais, initialize=P_UMDestino_dict)
    P_UMDestino = model.P_UMDestino  
    #print("P_UMDestino = ",P_UMDestino.display())

    #Duração do Voo
    #   Conversao de datetime para minutos
    P_DuracaoDoVooDatetime_dict = df_proginicial.set_index('Voo')['DuracaoDoVoo'].to_dict()
    P_DuracaoDoVoo_dict = Func_ConversaoDatetimeParaMinutosParametros(P_DuracaoDoVooDatetime_dict)
    #   Transformação de lista em parâmetro para modelo
    model.P_DuracaoDoVoo = pyo.Param(S_VoosReais, initialize=P_DuracaoDoVoo_dict)
    P_DuracaoDoVoo = model.P_DuracaoDoVoo  
    #print("P_DuracaoDoVoo= ",P_DuracaoDoVoo.display())

    # Aeronave inicial
    P_AeronaveInicialString_dict = df_proginicial.set_index('Voo')['AeronaveInicial'].to_dict()
    # Convertendo para um parâmetro de 2 índices binário, em formato de dicionário
    P_AeronaveInicial = {}
    for i in S_VoosReais:
        for h in S_Aeronaves:
            if P_AeronaveInicialString_dict[i] == h:
                P_AeronaveInicial[i,h] = 1
            else:
                P_AeronaveInicial[i,h] = 0

    # Declarando o dicionário como parâmetro         
    model.P_AeronaveInicial = pyo.Param(S_VoosReais, S_Aeronaves, initialize=P_AeronaveInicial)
    P_AeronaveInicial = model.P_AeronaveInicial
    #print("P_AeronaveInicial = ",P_AeronaveInicial.display())

    # Tempo de Permanência
    #   Conversao de datetime para minutos
    P_TempoDePermanenciaDatetime_dict = df_proginicial.set_index('Voo')['TempoDePermanencia'].to_dict()
    P_TempoDePermanencia_dict = Func_ConversaoDatetimeParaMinutosParametros(P_TempoDePermanenciaDatetime_dict)
    #   Transformação de lista em parâmetro para modelo
    model.P_TempoDePermanencia = pyo.Param(S_VoosReais, initialize=P_TempoDePermanencia_dict)
    P_TempoDePermanencia = model.P_TempoDePermanencia 
    #print("P_TempoDePermanencia = ",P_TempoDePermanencia.display())

    # Tipo de Aeronave
    P_TipoDeAeronave_dict = df_aeronaves.set_index('Aeronave')['TipoDaAeronave'].to_dict()
    model.P_TipoDeAeronave = pyo.Param(S_Aeronaves, initialize=P_TipoDeAeronave_dict)
    P_TipoDeAeronave = model.P_TipoDeAeronave 
    #print("P_TipoDeAeronave = ",P_TipoDeAeronave.display())

    # Compatibilidade
    # Como esse parâmetro possui mais de um índice, é necessária uma manipulação prévia
    # Além disso, o dataframe com os dados deste parâmetro está num formato em que um dos indices (S_Voos) está na coluna e o outro (S_Aeronaves) está como cabeçalho
    # Para isso, os passos abaixo são seguidos:
    # Passo 1) usar a função .melt para alterar o formato do dataframe, transferindo o cabeçalho para uma nova coluna:
    df_compatibilidade_mod= df_compatibilidade.melt(id_vars=['Voo'], var_name='Aeronaves', value_name='Compatibilidade')
    # Passo 2) Create the dictionary in the (S_VoosReais, S_UM): Value format, que é o formato que a função pyo.Param aceita os dados de um parâmetro multiíndice
    P_Compatibilidade_dict = {(row['Voo'], row['Aeronaves']): row['Compatibilidade'] for _, row in df_compatibilidade_mod.iterrows()}
    # Passo 3) Por fim, realizar a atribuição ao parâmetro normalmente
    model.P_Compatibilidade = pyo.Param(S_VoosReais, S_Aeronaves, initialize=P_Compatibilidade_dict)
    P_Compatibilidade = model.P_Compatibilidade 
    # print("P_Compatibilidade = ",P_Compatibilidade.display())

    ##################################################################################################### Variáveis e FO
    # Variáveis do modelo
    # X(i,P,h)
    model.V_X3 = pyo.Var(S_VoosReais, S_Posicoes, S_Aeronaves, domain = pyo.Binary, bounds = [0,1])
    V_X3 = model.V_X3 
    #Y(i,h)
    #model.V_Y = pyo.Var(S_VoosReais, S_Aeronaves, domain = pyo.Binary, bounds = [0,1])
    #V_Y = model.V_Y 
    #Z(i,j)
    model.V_Z = pyo.Var(S_VoosReais, S_VoosReais, domain = pyo.Binary, bounds = [0,1])
    V_Z = model.V_Z
    #V(h)
    #model.V_V = pyo.Var(S_Aeronaves, domain = pyo.Binary, bounds = [0,1])
    #V_V= model.V_V
    #BI(i)
    model.V_BI = pyo.Var(S_VoosReais, domain = pyo.Binary, bounds = [0,1])
    V_BI = model.V_BI
    #BII(i)
    model.V_BII = pyo.Var(S_VoosReais, domain = pyo.Binary, bounds = [0,1])
    V_BII = model.V_BII
    #DT(i)
    model.V_DT = pyo.Var(S_VoosReais, domain = pyo.NonNegativeReals)
    V_DT = model.V_DT
    #AT(i)
    model.V_AT = pyo.Var(S_VoosReais, domain = pyo.NonNegativeReals)
    V_AT = model.V_AT
    #D(i)
    model.V_D = pyo.Var(S_VoosReais, domain = pyo.NonNegativeReals)
    V_D = model.V_D

    #Funcao Objetivo
    V_FO = (
            P_PenCancelamentoComitiva * (len(S_VoosComitiva) - sum(V_X3[vooC,p,h] for vooC in S_VoosComitiva for p in S_Posicoes for h in S_Aeronaves))
        +P_PenCancelamento2Dias * (len(S_VoosT2) - sum(V_X3[vooT2,p,h] for vooT2 in S_VoosT2 for p in S_Posicoes for h in S_Aeronaves))
        +P_PenCancelamento1Dia * (len(S_VoosT1) - sum(V_X3[vooT1,p,h] for vooT1 in S_VoosT1 for p in S_Posicoes for h in S_Aeronaves))
        +P_PenCancelamentoTabela * (len(S_VoosTabela) - sum(V_X3[vooTab,p,h] for vooTab in S_VoosTabela for p in S_Posicoes for h in S_Aeronaves))
        +P_PenUsoAeronaveSpot * sum(V_X3[voo,S_Posicoes.at(1),hSpot] for voo in S_VoosReais for hSpot in S_AeronavesSpot)
        +P_PenUsoAeronavePool * sum(V_X3[voo,S_Posicoes.at(1),hPool] for voo in S_VoosReais for hPool in S_AeronavesPool)
        +P_PenUsoAeronaveComum * sum(V_X3[voo,S_Posicoes.at(1),hComum] for voo in S_VoosReais for hComum in S_AeronavesComum)
        +P_PenAtrasoTipo2 * sum(V_BII[vooTabelaComitiva] for vooTabelaComitiva in S_VoosTabelaComitiva)
        +P_PenAtrasoTipo1 * sum(V_BI[vooTabelaComitiva] for vooTabelaComitiva in S_VoosTabelaComitiva)
        +P_PenAtrasoMinuto * sum(V_D[vooTodos] for vooTodos in S_VoosReais)
        +P_PenTrocaAeronave * sum(V_X3[vooTabelaComitiva,p,h] * (1 - P_AeronaveInicial[vooTabelaComitiva,h]) for vooTabelaComitiva in S_VoosTabelaComitiva for p in S_Posicoes for h in S_Aeronaves)
    )

    model.obj = pyo.Objective(expr = V_FO, sense = pyo.minimize)

    # Restrições ################################################################################################
    # 4.58 C_UmVooPorPosicaoAeronave
    model.C_UmVooPorPosicaoAeronave = pyo.Constraint(S_VoosReais,
                                                rule = lambda model, i: 
                                                    sum(V_X3[i,p,h] for p in S_Posicoes for h in S_Aeronaves)
                                                        <= 
                                                        1)
    # 4.59 C_ReciprocaUmVooPorPosicaoAeronave
    model.C_ReciprocaUmVooPorPosicaoAeronave = pyo.Constraint(S_Posicoes, S_Aeronaves,
                                                rule = lambda model, p,h: 
                                                    sum(V_X3[i,p,h] for i in S_VoosReais)
                                                        <= 
                                                        1)

    # 4.60 C_Precedencia
    model.C_Precedencia = pyo.Constraint(S_PosicoesExcetoUltima,S_Aeronaves,
                                                rule = lambda model, p, h: 
                                                    sum(V_X3[i,p,h] for i in S_VoosReais)
                                                        >=
                                                    #sum(V_X3[j,p_aux,h] for j in S_VoosReais if p_aux == p+1))
                                                    sum(V_X3[j,p+1,h] for j in S_VoosReais))

    # 4.61 C_OcupacaoComitiva
    model.C_OcupacaoComitiva = pyo.Constraint(S_VoosComitiva, S_VoosReais, S_PosicoesExcetoUltima, S_Aeronaves,
                                                rule = lambda model, i,j,p,h: 
                                                    sum(V_X3[j,p_aux,h] for p_aux in S_Posicoes if p_aux >= p+1)
                                                        <=
                                                        1 - V_X3[i,p,h])
    
     # 4.62 C_SequenciaCronologiCA
    model.C_SequenciaCronologica = pyo.Constraint(S_VoosReais, S_VoosReais, S_Aeronaves, S_PosicoesExcetoUltima,
                                                        rule = lambda model, i,j, h, p: 
                                                        V_DT[j]
                                                            >=
                                                        V_AT[i] 
                                                        + P_TurnaroundTime
                                                        - P_FimDoHorizonte * (2 - V_X3[i,p,h] - V_X3[j,p+1,h])
                                                        #if i != j else pyo.Constraint.Skip
                                                        )
    # 4.63 C_HorarioDeChegada
    model.C_HorarioDeChegada = pyo.Constraint(S_VoosReais,
                                                        rule = lambda model, i: 
                                                        V_AT[i]
                                                            ==
                                                        V_DT[i] + P_DuracaoDoVoo[i]*sum(V_X3[i,p,h] for p in S_Posicoes for h in S_Aeronaves))
    # 4.64 C_ChegadaDentroDaJanelaDeTempo - ok -tc5
    model.C_ChegadaDentroDaJanelaDeTempo = pyo.Constraint(S_VoosReais,
                                                        rule = lambda model, i: 
                                                        V_AT[i]
                                                            <=
                                                        P_FimDoHorizonte * sum(V_X3[i,p,h] for p in S_Posicoes for h in S_Aeronaves)) 
    # 4.65 C_PartidaAposOHorarioPrevisto
    model.C_PartidaAposOHorarioPrevisto = pyo.Constraint(S_VoosReais,
                                                        rule = lambda model, i: 
                                                        P_HorarioInicial[i] * sum(V_X3[i,p,h] for p in S_Posicoes for h in S_Aeronaves) 
                                                            <=
                                                        V_DT[i])
    # 4.66 C_AtivacaoDaPrecedencia1
    model.C_AtivacaoDaPrecedencia1 = pyo.Constraint(S_VoosReais, S_VoosReais,
                                                        rule = lambda model, i,j: 
                                                        V_DT[j]
                                                        -
                                                        V_DT[i]
                                                        <=
                                                        P_FimDoHorizonte*(V_Z[i,j] + 2 - sum(V_X3[i,p,h] for p in S_Posicoes for h in S_Aeronaves) - sum(V_X3[j,p,h] for p in S_Posicoes for h in S_Aeronaves))
                                                        if i != j else pyo.Constraint.Skip # garante que a restrição só será criada se i != j 
                                                    )

    # 4.67 C_ApenasUmaPrecedencia
    model.C_ApenasUmaPrecedencia = pyo.Constraint(S_VoosReais, S_VoosReais,
                                                        rule = lambda model, i,j: 
                                                        V_Z[i,j] + V_Z[j,i]
                                                        <=
                                                        1
                                                        if i != j else pyo.Constraint.Skip # garante que a restrição só será criada se i != j 
                                                    )
    # 4.68 C_AtivacaoDaPrecedencia2
    model.C_AtivacaoDaPrecedencia2 = pyo.Constraint(S_VoosReais, S_VoosReais,
                                                        rule = lambda model, i,j: 
                                                        V_Z[i,j] + V_Z[j,i]
                                                        >=
                                                        sum(V_X3[i,p,h] for p in S_Posicoes for h in S_Aeronaves) + sum(V_X3[j,p,h] for p in S_Posicoes for h in S_Aeronaves) - 1
                                                        if i != j else pyo.Constraint.Skip # garante que a restrição só será criada se i != j 
                                                    )
    # 4.69 C_DesigualdadeValida
    model.C_DesigualdadeValida = pyo.Constraint(S_VoosReais,
                                                        rule = lambda model, i: 
                                                        sum(V_Z[i,j] for j in S_VoosReais)
                                                        <=
                                                        len(S_VoosReais) * sum(V_X3[i,p,h] for p in S_Posicoes for h in S_Aeronaves)
                                                    )     
    # 4.70 C_TipoDeAtraso
    model.C_TipoDeAtraso = pyo.Constraint(S_VoosTabelaComitiva,
                                                        rule = lambda model, i0C: 
                                                        V_BI[i0C] + V_BII[i0C]
                                                        <=
                                                        1)
    # 4.71 C_ValorDoAtraso
    model.C_ValorDoAtraso = pyo.Constraint(S_VoosTabelaComitiva,
                                                        rule = lambda model, i0C: 
                                                        V_D[i0C]
                                                        <=
                                                        P_AtrasoLimite1 * V_BI[i0C] + P_AtrasoLimite2 * V_BII[i0C]
                                                        ) 
    # 4.72 C_DeterminaValorDePartida
    model.C_DeterminaValorDePartida = pyo.Constraint(S_VoosReais,
                                                        rule = lambda model, i: 
                                                        V_DT[i]
                                                            <=
                                                        P_HorarioInicial[i] * sum(V_X3[i,p,h] for p in S_Posicoes for h in S_Aeronaves) + V_D[i])
    # 4.73 C_TempoDePermanencia - ok - oc2
    model.C_TempoDePermanencia = pyo.Constraint(S_VoosReais,S_VoosReais,S_UM,
                                                        rule = lambda model, i,j,um: 
                                                        V_DT[j] - V_DT[i]
                                                        >=
                                                        P_TempoDePermanencia[i] * V_Z[i,j] - P_FimDoHorizonte * (1 - V_Z[i,j])
                                                        if ((i != j) and (P_UMDestino[i] == P_UMDestino[j])) else pyo.Constraint.Skip
                                                    )
    # 4.74 C_TempoDeSeguranca - ok - oc1
    model.C_TempoDeSeguranca = pyo.Constraint(S_VoosReais,S_VoosReais,
                                                        rule = lambda model, i,j: 
                                                        V_DT[j] - V_DT[i]
                                                        >=
                                                        P_TempoDeSeguranca * V_Z[i,j] - P_FimDoHorizonte * (1 - V_Z[i,j])
                                                        if i != j else pyo.Constraint.Skip
                                                    )

    # Voo i incompatível com aeronave h para V_X3
    for i in S_VoosReais:
        for h in S_Aeronaves:
            for p in S_Posicoes:
                if P_Compatibilidade[i,h] == 0:
                    V_X3[i,p,h].fix(0)


    # Respeitar precedência de voos

    for i0 in S_VoosTabela:
        for itransf in S_VoosTransferencia:
    #       for um in S_UM:
                if P_UMDestino[i0] == P_UMDestino[itransf] and i0 != itransf :
                    V_Z[i0,itransf].fix(0)      

    # Informações do Modelo
    # Count all variables in the model
    P_total_variables[instancia] = len(list(model.component_data_objects(Var)))

    # Count integer variables
    P_integer_variables[instancia] = len([v for v in model.component_data_objects(Var) if v.domain == Integers])

    # Count binary variables
    P_binary_variables[instancia] = len([v for v in model.component_data_objects(Var) if v.domain == Binary])

    # Count all constraints in the model
    P_total_constraints[instancia] = len(list(model.component_data_objects(Constraint)))

    # Print the results
    print(f"Total number of variables: {P_total_variables[instancia]}")
    print(f"Total number of integer variables: {P_integer_variables[instancia]}")
    print(f"Total number of binary variables: {P_binary_variables[instancia]}")
    print(f"Total number of constraints: {P_total_constraints[instancia]}")

    #opt = SolverFactory(solver_selecionado, executable='C:\\Users\\mateu\\Desktop\\Estudos\\Solvers\\SCIP\\scip-9.2.0\\SCIPOptSuite-9.2.0-win64.exe')
    opt = SolverFactory(solver_selecionado)

    # Verificando se o solver selecionado existe
    #print(opt.available())

    # Nome da rodada
    Ps_NomeDaRodada[instancia] = Ps_NomeDaInstancia + "_" + solver_selecionado + "_" + f"{P_HoraDaRodadaTimeStamp}"

    # Definindo as opções do solver
    # Set solver options for GLPK
    if solver_selecionado == 'glpk':
        opt.options['tmlim'] = 3600  # Set time limit (seconds)
        opt.options['mipgap'] = 0.00  # Set optimality gap (percentage)
        #opt.options['threads'] = 4  # Set the number of threads
        #solver.options['log'] = f"{Ps_NomeDaRodada}.txt"  # Optional: Log file (GLPK doesn't directly support this in Pyomo)

    # CBC
    if solver_selecionado == 'cbc':
        opt.options['seconds'] = 3600  # Set a time limit (optional)
        opt.options['ratio'] = 0.00  # Set optimality gap (optional)
        opt.options['threads'] = 4  # set number of threads (optional)
        opt.options['log'] = 1  # Enable verbose logging
        opt.options['allowableGap'] = 0 # Ensure the absolute gap is 0
        #opt.options['logFile'] = f"{Ps_NomeDaRodada}.txt" # escreve o log da rodada

    #Gurobi
    if solver_selecionado == 'gurobi':
        opt.options['TimeLimit'] = 3600  # Set a time limit (optional)
        opt.options['MIPGap'] = 0.00  # Set optimality gap (optional)
        opt.options['Threads'] = 4  # set number of threads (optional)
        #opt.options['LogFile'] = f"{Ps_NomeDaRodada}.txt" # escreve o log da rodada

    # CPLEX
    if solver_selecionado == 'cplex':
        opt.options['TimeLimit'] = 3600  # Set a time limit (optional)
        opt.options['mip_tolerances_mipgap'] = 0.00  # Set optimality gap (optional)
        opt.options['threads'] = 4 # set number of threads (optional)
        #opt.options['LogFile'] = f"{Ps_NomeDaRodada}.txt" # escreve o log da rodada

    # HiGHS
    if (solver_selecionado == 'appsi_highs') or (solver_selecionado == 'highs'):
        opt.options['time_limit'] = 3600  # Set a time limit (optional)
        opt.options['mip_rel_gap'] = 0.00  # Set optimality gap (optional)
        opt.options['threads'] = 4 # set number of threads (optional)
        #opt.options['log_file'] = f"{Ps_NomeDaRodada}.txt" # escreve o log da rodada

    # MOSEK
    if solver_selecionado == 'mosek':
        # Set logging file (this is for MOSEK output)
        #opt.options['logfile'] = f"{Ps_NomeDaRodada}.txt"  # Log file path
        # Set time limit (in seconds)
        opt.options['dparam.optimizer_max_time'] = 3600  # 1 hour limit
        # Set the optimality gap (optional)
        opt.options['dparam.mio_rel_gap_const'] = 0.00001  # 0% gap for exact solution
        # Set number of threads (optional)
        opt.options['iparam.num_threads'] = 4  # Set to 4 threads
    
    # SCIP
    if solver_selecionado == 'scip':       
        # Set SCIP options
        opt.options['limits/time'] = 3600         # Set time limit to 3600 seconds
        opt.options['limits/gap'] = 0.00         # Set optimality gap
        opt.options['parallel/maxnthreads'] = 4  # Use 4 threads

    # Solving the model
    # Relaxação linear
    if relaxacao_linear == 1:
        xfrm = TransformationFactory('core.relax_integer_vars')
        relaxed_model = xfrm.apply_to(model)
    
    start_time[instancia] = datetime.now()
    results = opt.solve(model, tee=True)
    #results = opt.solve(model)   
    end_time[instancia] = datetime.now()
    # Resultados
    print("Resultados da rodada: ", Ps_NomeDaRodada[instancia], f"Para o solver {solver_selecionado}")
    # Retrieve the objective value of the incumbent solution (best integer solution found)
    P_SOL_incumbent_solution[instancia] = model.obj()

    # Retrieve solver results
    P_SOL_solver_status[instancia] = results.solver.status
    #P_SOL_termination_condition[instancia] = results.solver.termination_condition
    P_SOL_solver_time[instancia] = results.solver.time if hasattr(results.solver, 'time') else None # Time spent solving the model    
    
    # Retrieve the best bound (only for MIP problems)
    P_SOL_best_bound[instancia] = results.solver.best_bound if hasattr(results.solver, 'best_bound') else None

    # Retrieve the optimality gap (only for MIP problems)
    P_SOL_optimality_gap[instancia] = results.solver.optimality_gap if hasattr(results.solver, 'optimality_gap') else None

    #P_SOL_optimality_gap = results.solver.get('mipgap', None)

    # Output the results
    print(f"Incumbent Solution: {P_SOL_incumbent_solution[instancia]}")
    #print(f"Best Bound: {P_SOL_best_bound}")
    #print(f"Optimality Gap: {P_SOL_optimality_gap}")
    print(f"Solver Status: {P_SOL_solver_status[instancia]}")
    #print(f"Termination Condition: {P_SOL_termination_condition}")
    print(f"Solver Time: {P_SOL_solver_time[instancia]} seconds")     

    elapsed_time[instancia] = end_time[instancia] - start_time[instancia]
# Out:
# [1, 3, 4, 6, 7, 8, 9, 10]
# Ps_NomeDaInstancia =  i11_Simulado
# S_Posicoes =  [1, 2, 3, 4, 5]
# S_PosicoesExcetoUltima =  [1, 2, 3, 4]
# P_DuracaoDoVoo : Size=11, Index=S_VoosReais, Domain=Any, Default=None, Mutable=False
#     Key : Value
#       1 :   104
#       2 :    93
#       3 :    91
#       4 :   103
#       5 :    79
#       6 :    87
#       7 :    85
#       8 :    87
#       9 :    73
#      10 :   100
#      11 :    79
# P_DuracaoDoVoo=  None
# Ps_NomeDaInstancia =  i11_Simulado
# WARNING: Implicitly replacing the Component attribute P_HorarioInicial
# (type=<class 'pyomo.core.base.param.IndexedParam'>) on block unknown with a
# new Component (type=<class 'pyomo.core.base.param.IndexedParam'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# WARNING: Implicitly replacing the Component attribute P_UMDestino (type=<class
# 'pyomo.core.base.param.IndexedParam'>) on block unknown with a new Component
# (type=<class 'pyomo.core.base.param.IndexedParam'>). This is usually
# indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# WARNING: Implicitly replacing the Component attribute P_DuracaoDoVoo
# (type=<class 'pyomo.core.base.param.IndexedParam'>) on block unknown with a
# new Component (type=<class 'pyomo.core.base.param.IndexedParam'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# WARNING: Implicitly replacing the Component attribute P_AeronaveInicial
# (type=<class 'pyomo.core.base.param.IndexedParam'>) on block unknown with a
# new Component (type=<class 'pyomo.core.base.param.IndexedParam'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# WARNING: Implicitly replacing the Component attribute P_TempoDePermanencia
# (type=<class 'pyomo.core.base.param.IndexedParam'>) on block unknown with a
# new Component (type=<class 'pyomo.core.base.param.IndexedParam'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# WARNING: Implicitly replacing the Component attribute P_TipoDeAeronave
# (type=<class 'pyomo.core.base.param.IndexedParam'>) on block unknown with a
# new Component (type=<class 'pyomo.core.base.param.IndexedParam'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# WARNING: Implicitly replacing the Component attribute P_Compatibilidade
# (type=<class 'pyomo.core.base.param.IndexedParam'>) on block unknown with a
# new Component (type=<class 'pyomo.core.base.param.IndexedParam'>). This is
# usually indicative of a modelling error. To avoid this warning, use
# block.del_component() and block.add_component().
# <string>:14: SyntaxWarning: invalid escape sequence '\{'
# <>:14: SyntaxWarning: invalid escape sequence '\{'
# <>:14: SyntaxWarning: invalid escape sequence '\M'
# <string>:14: SyntaxWarning: invalid escape sequence '\{'
# <>:14: SyntaxWarning: invalid escape sequence '\{'
# <>:14: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\mateu\AppData\Local\Temp\ipykernel_27228\1219184466.py:14: SyntaxWarning: invalid escape sequence '\{'
#   Ps_CaminhoDaPlanilha = f"G:\Meu Drive\Planilhas para Estudos\{instancia}.xlsx"
# C:\Users\mateu\AppData\Local\Temp\ipykernel_27228\1219184466.py:14: SyntaxWarning: invalid escape sequence '\M'
#   Ps_CaminhoDaPlanilha = f"G:\Meu Drive\Planilhas para Estudos\{instancia}.xlsx"
# Total number of variables: 341
# Total number of integer variables: 0
# Total number of binary variables: 308
# Total number of constraints: 2071
# Welcome to the CBC MILP Solver
# Version: 2.10.12
# Build Date: Aug 20 2024
#
# command line - C:\Users\mateu\Desktop\Estudos\Solvers\CBC\Cbc-releases.2.10.12-w64-msvc17-md\bin\cbc.exe -seconds 3600 -ratio 0.0 -threads 4 -printingOptions all -import C:\Users\mateu\AppData\Local\Temp\tmpumtt8gw9.pyomo.lp -stat=1 -solve -solu C:\Users\mateu\AppData\Local\Temp\tmpumtt8gw9.pyomo.soln (default strategy 1)
# seconds was changed from 1e+100 to 3600
# ratioGap was changed from 0 to 0
# No match for threads - ? for list of commands
# No match for 4 - ? for list of commands
# Option for printingOptions changed from normal to all
# Presolve 1795 (-276) rows, 272 (-12) columns and 10271 (-1755) elements
# Statistics for presolved model
# Original problem has 250 integers (250 of which binary)
# Presolved problem has 239 integers (239 of which binary)
# ==== 130 zero objective 16 different
# ==== absolute objective values 16 different
# ==== for integers 108 zero objective 15 different
# ==== for integers absolute objective values 15 different
# ===== end objective counts
#
#
# Problem has 1795 rows, 272 columns (142 with objective) and 10271 elements
# There are 3 singletons with objective
# Column breakdown:
# 33 of type 0.0->inf, 0 of type 0.0->up, 0 of type lo->inf,
# 0 of type lo->up, 0 of type free, 0 of type fixed,
# 0 of type -inf->0.0, 0 of type -inf->up, 239 of type 0.0->1.0
# Row breakdown:
# 11 of type E 0.0, 0 of type E 1.0, 0 of type E -1.0,
# 0 of type E other, 0 of type G 0.0, 0 of type G 1.0,
# 0 of type G other, 64 of type L 0.0, 142 of type L 1.0,
# 1578 of type L other, 0 of type Range 0.0->1.0, 0 of type Range other,
# 0 of type Free
# Continuous objective value is 46.5 - 0.01 seconds
# Cgl0004I processed model has 1795 rows, 272 columns (239 integer (239 of which binary)) and 10271 elements
# Cbc0038I Initial state - 65 integers unsatisfied sum - 13.9382
# Cbc0038I Pass   1: suminf.    3.24622 (38) obj. 201.299 iterations 122
# Cbc0038I Pass   2: suminf.    2.43489 (36) obj. 176.716 iterations 17
# Cbc0038I Pass   3: suminf.    1.88771 (31) obj. 179.028 iterations 22
# Cbc0038I Pass   4: suminf.    8.08812 (51) obj. 633.258 iterations 104
# Cbc0038I Pass   5: suminf.    8.06304 (53) obj. 659.653 iterations 13
# Cbc0038I Pass   6: suminf.    6.97822 (52) obj. 613.592 iterations 15
# Cbc0038I Pass   7: suminf.    6.65852 (49) obj. 537.185 iterations 8
# Cbc0038I Pass   8: suminf.    6.42306 (44) obj. 425.481 iterations 20
# Cbc0038I Pass   9: suminf.    6.85018 (35) obj. 319.981 iterations 85
# Cbc0038I Pass  10: suminf.    3.74054 (35) obj. 288.068 iterations 39
# Cbc0038I Pass  11: suminf.    3.16019 (33) obj. 269.132 iterations 39
# Cbc0038I Pass  12: suminf.    2.73458 (33) obj. 293.677 iterations 8
# Cbc0038I Pass  13: suminf.    2.37245 (34) obj. 288.439 iterations 5
# Cbc0038I Pass  14: suminf.    7.24618 (39) obj. 719.917 iterations 92
# Cbc0038I Pass  15: suminf.    7.17150 (38) obj. 750.736 iterations 27
# Cbc0038I Pass  16: suminf.    7.12740 (29) obj. 633.217 iterations 71
# Cbc0038I Pass  17: suminf.    5.69126 (30) obj. 665.283 iterations 27
# Cbc0038I Pass  18: suminf.    5.38563 (30) obj. 665.283 iterations 1
# Cbc0038I Pass  19: suminf.    4.82968 (29) obj. 738.309 iterations 63
# Cbc0038I Pass  20: suminf.    3.83664 (29) obj. 822.759 iterations 26
# Cbc0038I Pass  21: suminf.    3.83603 (28) obj. 822.418 iterations 1
# Cbc0038I Pass  22: suminf.    4.56325 (22) obj. 770.075 iterations 39
# Cbc0038I Pass  23: suminf.    3.73622 (24) obj. 902.252 iterations 16
# Cbc0038I Pass  24: suminf.    3.64183 (29) obj. 918.083 iterations 22
# Cbc0038I Pass  25: suminf.    3.64012 (30) obj. 919.8 iterations 5
# Cbc0038I Pass  26: suminf.    5.09677 (13) obj. 756.915 iterations 50
# Cbc0038I Pass  27: suminf.    2.70391 (26) obj. 1022.3 iterations 51
# Cbc0038I Pass  28: suminf.    5.00000 (10) obj. 757.205 iterations 41
# Cbc0038I Pass  29: suminf.    1.91039 (13) obj. 1065.94 iterations 31
# Cbc0038I Pass  30: suminf.    1.65240 (15) obj. 1094.81 iterations 28
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 82 integers at bound fixed and 6 continuous
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 1547 rows 184 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.14 seconds)
# Cbc0038I Full problem 1796 rows 272 columns, reduced to 1788 rows 272 columns - too large
# Cbc0038I After 0.15 seconds - Feasibility pump exiting - took 0.11 seconds
# Cbc0031I 18 added rows had average density of 38
# Cbc0013I At root node, 18 cuts changed objective from 46.5 to 121.99995 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 10 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.326 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 632 row cuts average 93.4 elements, 0 column cuts (0 active)  in 0.055 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.060 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 21 row cuts average 5.9 elements, 0 column cuts (0 active)  in 0.119 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.153 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 144 row cuts average 71.4 elements, 0 column cuts (0 active)  in 0.059 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 31 row cuts average 17.2 elements, 0 column cuts (0 active)  in 0.059 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 121.99995 (1.39 seconds)
# Cbc0016I Integer solution of 167.722 found by strong branching after 3086 iterations and 45 nodes (2.33 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 464 rows 63 columns
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 247 rows 46 columns
# Cbc0010I After 100 nodes, 41 on tree, 167.722 best solution, best possible 121.99995 (3.00 seconds)
# Cbc0016I Integer solution of 157.669 found by strong branching after 14986 iterations and 195 nodes (4.11 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 274 rows 49 columns
# Cbc0010I After 200 nodes, 54 on tree, 157.669 best solution, best possible 121.99995 (4.24 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 239 rows 56 columns
# Cbc0010I After 300 nodes, 91 on tree, 157.669 best solution, best possible 121.99995 (7.07 seconds)
# Cbc0010I After 400 nodes, 115 on tree, 157.669 best solution, best possible 121.99995 (8.48 seconds)
# Cbc0010I After 500 nodes, 147 on tree, 157.669 best solution, best possible 121.99995 (10.69 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 620 rows 88 columns
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 495 rows 84 columns
# Cbc0010I After 600 nodes, 165 on tree, 157.669 best solution, best possible 121.99995 (12.11 seconds)
# Cbc0010I After 700 nodes, 180 on tree, 157.669 best solution, best possible 121.99995 (13.78 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 348 rows 67 columns
# Cbc0010I After 800 nodes, 198 on tree, 157.669 best solution, best possible 121.99995 (15.28 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 467 rows 78 columns
# Cbc0010I After 900 nodes, 215 on tree, 157.669 best solution, best possible 121.99995 (16.86 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 376 rows 56 columns
# Cbc0010I After 1000 nodes, 227 on tree, 157.669 best solution, best possible 121.99995 (17.82 seconds)
# Cbc0010I After 1100 nodes, 242 on tree, 157.669 best solution, best possible 121.99995 (18.53 seconds)
# Cbc0010I After 1200 nodes, 234 on tree, 157.669 best solution, best possible 121.99995 (19.13 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 614 rows 86 columns
# Cbc0010I After 1300 nodes, 221 on tree, 157.669 best solution, best possible 121.99995 (19.82 seconds)
# Cbc0010I After 1400 nodes, 217 on tree, 157.669 best solution, best possible 121.99995 (20.20 seconds)
# Cbc0010I After 1500 nodes, 204 on tree, 157.669 best solution, best possible 121.99995 (20.60 seconds)
# Cbc0010I After 1600 nodes, 197 on tree, 157.669 best solution, best possible 121.99995 (21.13 seconds)
# Cbc0010I After 1700 nodes, 188 on tree, 157.669 best solution, best possible 121.99995 (21.74 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 488 rows 81 columns
# Cbc0010I After 1800 nodes, 184 on tree, 157.669 best solution, best possible 121.99995 (22.36 seconds)
# Cbc0010I After 1900 nodes, 170 on tree, 157.669 best solution, best possible 121.99995 (22.81 seconds)
# Cbc0010I After 2000 nodes, 158 on tree, 157.669 best solution, best possible 121.99995 (23.21 seconds)
# Cbc0010I After 2100 nodes, 145 on tree, 157.669 best solution, best possible 121.99995 (23.98 seconds)
# Cbc0010I After 2200 nodes, 129 on tree, 157.669 best solution, best possible 121.99995 (24.44 seconds)
# Cbc0010I After 2300 nodes, 127 on tree, 157.669 best solution, best possible 121.99995 (25.20 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 304 rows 56 columns
# Cbc0010I After 2400 nodes, 126 on tree, 157.669 best solution, best possible 121.99995 (25.86 seconds)
# Cbc0004I Integer solution of 157.169 found after 279349 iterations and 2422 nodes (25.95 seconds)
# Cbc0010I After 2500 nodes, 130 on tree, 157.169 best solution, best possible 121.99995 (26.84 seconds)
# Cbc0010I After 2600 nodes, 147 on tree, 157.169 best solution, best possible 121.99995 (28.01 seconds)
# Cbc0010I After 2700 nodes, 152 on tree, 157.169 best solution, best possible 121.99995 (28.61 seconds)
# Cbc0010I After 2800 nodes, 158 on tree, 157.169 best solution, best possible 121.99995 (29.38 seconds)
# Cbc0010I After 2900 nodes, 167 on tree, 157.169 best solution, best possible 121.99995 (30.11 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 434 rows 76 columns
# Cbc0010I After 3000 nodes, 179 on tree, 157.169 best solution, best possible 121.99995 (30.69 seconds)
# Cbc0010I After 3100 nodes, 188 on tree, 157.169 best solution, best possible 121.99995 (31.36 seconds)
# Cbc0010I After 3200 nodes, 205 on tree, 157.169 best solution, best possible 121.99995 (31.79 seconds)
# Cbc0010I After 3300 nodes, 233 on tree, 157.169 best solution, best possible 121.99995 (32.48 seconds)
# Cbc0010I After 3400 nodes, 252 on tree, 157.169 best solution, best possible 121.99995 (33.09 seconds)
# Cbc0010I After 3500 nodes, 268 on tree, 157.169 best solution, best possible 121.99995 (33.45 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 535 rows 78 columns
# Cbc0010I After 3600 nodes, 271 on tree, 157.169 best solution, best possible 121.99995 (33.89 seconds)
# Cbc0010I After 3700 nodes, 275 on tree, 157.169 best solution, best possible 121.99995 (34.22 seconds)
# Cbc0010I After 3800 nodes, 274 on tree, 157.169 best solution, best possible 121.99995 (34.69 seconds)
# Cbc0010I After 3900 nodes, 284 on tree, 157.169 best solution, best possible 121.99995 (35.14 seconds)
# Cbc0010I After 4000 nodes, 290 on tree, 157.169 best solution, best possible 121.99995 (35.73 seconds)
# Cbc0010I After 4100 nodes, 309 on tree, 157.169 best solution, best possible 121.99995 (36.54 seconds)
# Cbc0010I After 4200 nodes, 327 on tree, 157.169 best solution, best possible 121.99995 (37.12 seconds)
# Cbc0010I After 4300 nodes, 344 on tree, 157.169 best solution, best possible 121.99995 (37.79 seconds)
# Cbc0010I After 4400 nodes, 363 on tree, 157.169 best solution, best possible 121.99995 (38.63 seconds)
# Cbc0010I After 4500 nodes, 356 on tree, 157.169 best solution, best possible 121.99995 (38.87 seconds)
# Cbc0010I After 4600 nodes, 362 on tree, 157.169 best solution, best possible 121.99995 (39.43 seconds)
# Cbc0010I After 4700 nodes, 368 on tree, 157.169 best solution, best possible 121.99995 (40.01 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 282 rows 50 columns
# Cbc0010I After 4800 nodes, 364 on tree, 157.169 best solution, best possible 121.99995 (40.53 seconds)
# Cbc0010I After 4900 nodes, 360 on tree, 157.169 best solution, best possible 121.99995 (41.02 seconds)
# Cbc0010I After 5000 nodes, 359 on tree, 157.169 best solution, best possible 121.99995 (41.44 seconds)
# Cbc0010I After 5100 nodes, 367 on tree, 157.169 best solution, best possible 121.99995 (42.24 seconds)
# Cbc0010I After 5200 nodes, 349 on tree, 157.169 best solution, best possible 121.99995 (42.83 seconds)
# Cbc0010I After 5300 nodes, 314 on tree, 157.169 best solution, best possible 121.99995 (43.10 seconds)
# Cbc0004I Integer solution of 156.823 found after 470446 iterations and 5368 nodes (43.32 seconds)
# Cbc0010I After 5400 nodes, 265 on tree, 156.823 best solution, best possible 121.99995 (43.51 seconds)
# Cbc0010I After 5500 nodes, 268 on tree, 156.823 best solution, best possible 121.99995 (44.30 seconds)
# Cbc0010I After 5600 nodes, 277 on tree, 156.823 best solution, best possible 121.99995 (45.45 seconds)
# Cbc0010I After 5700 nodes, 281 on tree, 156.823 best solution, best possible 121.99995 (46.18 seconds)
# Cbc0010I After 5800 nodes, 289 on tree, 156.823 best solution, best possible 121.99995 (46.69 seconds)
# Cbc0010I After 5900 nodes, 291 on tree, 156.823 best solution, best possible 121.99995 (47.11 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 276 rows 50 columns
# Cbc0010I After 6000 nodes, 286 on tree, 156.823 best solution, best possible 121.99995 (47.55 seconds)
# Cbc0010I After 6100 nodes, 295 on tree, 156.823 best solution, best possible 121.99995 (48.12 seconds)
# Cbc0010I After 6200 nodes, 309 on tree, 156.823 best solution, best possible 121.99995 (48.54 seconds)
# Cbc0010I After 6300 nodes, 293 on tree, 156.823 best solution, best possible 121.99995 (48.99 seconds)
# Cbc0010I After 6400 nodes, 280 on tree, 156.823 best solution, best possible 121.99995 (49.40 seconds)
# Cbc0010I After 6500 nodes, 290 on tree, 156.823 best solution, best possible 121.99995 (50.38 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 471 rows 80 columns
# Cbc0010I After 6600 nodes, 295 on tree, 156.823 best solution, best possible 121.99995 (51.34 seconds)
# Cbc0010I After 6700 nodes, 302 on tree, 156.823 best solution, best possible 121.99995 (52.07 seconds)
# Cbc0010I After 6800 nodes, 301 on tree, 156.823 best solution, best possible 121.99995 (52.52 seconds)
# Cbc0010I After 6900 nodes, 323 on tree, 156.823 best solution, best possible 121.99995 (53.52 seconds)
# Cbc0010I After 7000 nodes, 342 on tree, 156.823 best solution, best possible 121.99995 (54.39 seconds)
# Cbc0010I After 7100 nodes, 363 on tree, 156.823 best solution, best possible 121.99995 (55.14 seconds)
# Cbc0010I After 7200 nodes, 370 on tree, 156.823 best solution, best possible 121.99995 (55.71 seconds)
# Cbc0010I After 7300 nodes, 380 on tree, 156.823 best solution, best possible 121.99995 (56.40 seconds)
# Cbc0010I After 7400 nodes, 395 on tree, 156.823 best solution, best possible 121.99995 (56.98 seconds)
# Cbc0010I After 7500 nodes, 424 on tree, 156.823 best solution, best possible 121.99995 (57.76 seconds)
# Cbc0010I After 7600 nodes, 446 on tree, 156.823 best solution, best possible 121.99995 (58.52 seconds)
# Cbc0010I After 7700 nodes, 458 on tree, 156.823 best solution, best possible 121.99995 (58.99 seconds)
# Cbc0010I After 7800 nodes, 462 on tree, 156.823 best solution, best possible 121.99995 (59.43 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 397 rows 68 columns
# Cbc0010I After 7900 nodes, 461 on tree, 156.823 best solution, best possible 121.99995 (59.91 seconds)
# Cbc0010I After 8000 nodes, 468 on tree, 156.823 best solution, best possible 121.99995 (60.58 seconds)
# Cbc0010I After 8100 nodes, 478 on tree, 156.823 best solution, best possible 121.99995 (60.91 seconds)
# Cbc0010I After 8200 nodes, 481 on tree, 156.823 best solution, best possible 121.99995 (61.29 seconds)
# Cbc0010I After 8300 nodes, 497 on tree, 156.823 best solution, best possible 121.99995 (61.62 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 519 rows 85 columns
# Cbc0010I After 8400 nodes, 507 on tree, 156.823 best solution, best possible 121.99995 (62.09 seconds)
# Cbc0010I After 8500 nodes, 523 on tree, 156.823 best solution, best possible 121.99995 (62.63 seconds)
# Cbc0010I After 8600 nodes, 544 on tree, 156.823 best solution, best possible 121.99995 (63.50 seconds)
# Cbc0010I After 8700 nodes, 554 on tree, 156.823 best solution, best possible 121.99995 (63.93 seconds)
# Cbc0010I After 8800 nodes, 556 on tree, 156.823 best solution, best possible 121.99995 (64.35 seconds)
# Cbc0010I After 8900 nodes, 549 on tree, 156.823 best solution, best possible 121.99995 (64.71 seconds)
# Cbc0010I After 9000 nodes, 548 on tree, 156.823 best solution, best possible 121.99995 (65.16 seconds)
# Cbc0010I After 9100 nodes, 537 on tree, 156.823 best solution, best possible 121.99995 (65.42 seconds)
# Cbc0010I After 9200 nodes, 517 on tree, 156.823 best solution, best possible 121.99995 (65.78 seconds)
# Cbc0010I After 9300 nodes, 502 on tree, 156.823 best solution, best possible 121.99995 (66.18 seconds)
# Cbc0010I After 9400 nodes, 499 on tree, 156.823 best solution, best possible 121.99995 (66.61 seconds)
# Cbc0010I After 9500 nodes, 494 on tree, 156.823 best solution, best possible 121.99995 (66.96 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 229 rows 49 columns
# Cbc0010I After 9600 nodes, 476 on tree, 156.823 best solution, best possible 121.99995 (67.38 seconds)
# Cbc0010I After 9700 nodes, 462 on tree, 156.823 best solution, best possible 121.99995 (67.96 seconds)
# Cbc0010I After 9800 nodes, 457 on tree, 156.823 best solution, best possible 121.99995 (68.66 seconds)
# Cbc0010I After 9900 nodes, 456 on tree, 156.823 best solution, best possible 121.99995 (69.10 seconds)
# Cbc0010I After 10000 nodes, 440 on tree, 156.823 best solution, best possible 121.99995 (69.42 seconds)
# Cbc0010I After 10100 nodes, 433 on tree, 156.823 best solution, best possible 121.99995 (69.86 seconds)
# Cbc0010I After 10200 nodes, 427 on tree, 156.823 best solution, best possible 121.99995 (70.37 seconds)
# Cbc0010I After 10300 nodes, 414 on tree, 156.823 best solution, best possible 121.99995 (70.90 seconds)
# Cbc0010I After 10400 nodes, 406 on tree, 156.823 best solution, best possible 121.99995 (71.42 seconds)
# Cbc0010I After 10500 nodes, 393 on tree, 156.823 best solution, best possible 121.99995 (71.86 seconds)
# Cbc0010I After 10600 nodes, 366 on tree, 156.823 best solution, best possible 121.99995 (72.28 seconds)
# Cbc0010I After 10700 nodes, 357 on tree, 156.823 best solution, best possible 121.99995 (72.72 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 285 rows 53 columns
# Cbc0010I After 10800 nodes, 346 on tree, 156.823 best solution, best possible 121.99995 (73.19 seconds)
# Cbc0010I After 10900 nodes, 332 on tree, 156.823 best solution, best possible 121.99995 (73.69 seconds)
# Cbc0010I After 11000 nodes, 328 on tree, 156.823 best solution, best possible 121.99995 (74.29 seconds)
# Cbc0010I After 11100 nodes, 365 on tree, 156.823 best solution, best possible 122.01 (79.65 seconds)
# Cbc0010I After 11200 nodes, 407 on tree, 156.823 best solution, best possible 122.148 (82.14 seconds)
# Cbc0010I After 11300 nodes, 448 on tree, 156.823 best solution, best possible 122.21333 (85.21 seconds)
# Cbc0010I After 11400 nodes, 484 on tree, 156.823 best solution, best possible 122.22333 (88.53 seconds)
# Cbc0010I After 11500 nodes, 524 on tree, 156.823 best solution, best possible 122.22333 (91.41 seconds)
# Cbc0010I After 11600 nodes, 568 on tree, 156.823 best solution, best possible 122.22851 (92.82 seconds)
# Cbc0010I After 11700 nodes, 608 on tree, 156.823 best solution, best possible 122.31842 (94.15 seconds)
# Cbc0010I After 11800 nodes, 649 on tree, 156.823 best solution, best possible 122.39887 (95.50 seconds)
# Cbc0010I After 11900 nodes, 695 on tree, 156.823 best solution, best possible 122.47599 (97.14 seconds)
# Cbc0010I After 12000 nodes, 726 on tree, 156.823 best solution, best possible 122.51123 (98.37 seconds)
# Cbc0010I After 12100 nodes, 769 on tree, 156.823 best solution, best possible 122.62167 (99.58 seconds)
# Cbc0010I After 12200 nodes, 812 on tree, 156.823 best solution, best possible 122.76024 (100.85 seconds)
# Cbc0010I After 12300 nodes, 852 on tree, 156.823 best solution, best possible 122.88896 (101.97 seconds)
# Cbc0010I After 12400 nodes, 890 on tree, 156.823 best solution, best possible 123.02332 (102.92 seconds)
# Cbc0010I After 12500 nodes, 935 on tree, 156.823 best solution, best possible 123.10874 (103.92 seconds)
# Cbc0010I After 12600 nodes, 978 on tree, 156.823 best solution, best possible 123.20301 (105.28 seconds)
# Cbc0010I After 12700 nodes, 1022 on tree, 156.823 best solution, best possible 123.2901 (106.38 seconds)
# Cbc0010I After 12800 nodes, 1066 on tree, 156.823 best solution, best possible 123.36965 (107.23 seconds)
# Cbc0010I After 12900 nodes, 1109 on tree, 156.823 best solution, best possible 123.45074 (108.49 seconds)
# Cbc0010I After 13000 nodes, 1146 on tree, 156.823 best solution, best possible 123.52466 (109.38 seconds)
# Cbc0010I After 13100 nodes, 1161 on tree, 156.823 best solution, best possible 123.52466 (109.78 seconds)
# Cbc0010I After 13200 nodes, 1152 on tree, 156.823 best solution, best possible 123.52466 (110.14 seconds)
# Cbc0010I After 13300 nodes, 1147 on tree, 156.823 best solution, best possible 123.52466 (110.53 seconds)
# Cbc0010I After 13400 nodes, 1149 on tree, 156.823 best solution, best possible 123.52466 (110.80 seconds)
# Cbc0010I After 13500 nodes, 1150 on tree, 156.823 best solution, best possible 123.52466 (111.42 seconds)
# Cbc0010I After 13600 nodes, 1152 on tree, 156.823 best solution, best possible 123.52466 (112.06 seconds)
# Cbc0010I After 13700 nodes, 1147 on tree, 156.823 best solution, best possible 123.52466 (112.63 seconds)
# Cbc0010I After 13800 nodes, 1148 on tree, 156.823 best solution, best possible 123.52466 (113.08 seconds)
# Cbc0010I After 13900 nodes, 1161 on tree, 156.823 best solution, best possible 123.52466 (113.43 seconds)
# Cbc0010I After 14000 nodes, 1156 on tree, 156.823 best solution, best possible 123.52466 (113.89 seconds)
# Cbc0010I After 14100 nodes, 1185 on tree, 156.823 best solution, best possible 123.67665 (114.88 seconds)
# Cbc0010I After 14200 nodes, 1213 on tree, 156.823 best solution, best possible 123.78999 (115.85 seconds)
# Cbc0010I After 14300 nodes, 1249 on tree, 156.823 best solution, best possible 123.94048 (116.89 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 344 rows 67 columns
# Cbc0010I After 14400 nodes, 1283 on tree, 156.823 best solution, best possible 124.04852 (117.75 seconds)
# Cbc0010I After 14500 nodes, 1306 on tree, 156.823 best solution, best possible 124.21 (118.50 seconds)
# Cbc0010I After 14600 nodes, 1338 on tree, 156.823 best solution, best possible 124.37177 (119.74 seconds)
# Cbc0010I After 14700 nodes, 1359 on tree, 156.823 best solution, best possible 124.53233 (120.49 seconds)
# Cbc0010I After 14800 nodes, 1381 on tree, 156.823 best solution, best possible 124.7659 (121.08 seconds)
# Cbc0010I After 14900 nodes, 1408 on tree, 156.823 best solution, best possible 124.97597 (121.94 seconds)
# Cbc0010I After 15000 nodes, 1445 on tree, 156.823 best solution, best possible 125.11914 (122.87 seconds)
# Cbc0010I After 15100 nodes, 1475 on tree, 156.823 best solution, best possible 125.44131 (123.79 seconds)
# Cbc0010I After 15200 nodes, 1507 on tree, 156.823 best solution, best possible 125.72067 (124.56 seconds)
# Cbc0010I After 15300 nodes, 1535 on tree, 156.823 best solution, best possible 126.0181 (125.45 seconds)
# Cbc0010I After 15400 nodes, 1562 on tree, 156.823 best solution, best possible 126.34333 (126.50 seconds)
# Cbc0010I After 15500 nodes, 1586 on tree, 156.823 best solution, best possible 126.47411 (127.48 seconds)
# Cbc0010I After 15600 nodes, 1623 on tree, 156.823 best solution, best possible 126.49995 (131.45 seconds)
# Cbc0010I After 15700 nodes, 1659 on tree, 156.823 best solution, best possible 126.49995 (132.95 seconds)
# Cbc0010I After 15800 nodes, 1689 on tree, 156.823 best solution, best possible 126.49995 (134.30 seconds)
# Cbc0010I After 15900 nodes, 1722 on tree, 156.823 best solution, best possible 126.49995 (136.32 seconds)
# Cbc0010I After 16000 nodes, 1756 on tree, 156.823 best solution, best possible 126.51 (138.54 seconds)
# Cbc0010I After 16100 nodes, 1795 on tree, 156.823 best solution, best possible 126.51 (139.12 seconds)
# Cbc0010I After 16200 nodes, 1826 on tree, 156.823 best solution, best possible 126.51 (139.77 seconds)
# Cbc0010I After 16300 nodes, 1843 on tree, 156.823 best solution, best possible 126.51 (140.45 seconds)
# Cbc0010I After 16400 nodes, 1880 on tree, 156.823 best solution, best possible 126.51 (141.45 seconds)
# Cbc0010I After 16500 nodes, 1907 on tree, 156.823 best solution, best possible 126.51408 (142.14 seconds)
# Cbc0010I After 16600 nodes, 1937 on tree, 156.823 best solution, best possible 126.53419 (142.72 seconds)
# Cbc0010I After 16700 nodes, 1971 on tree, 156.823 best solution, best possible 126.55413 (143.43 seconds)
# Cbc0010I After 16800 nodes, 1992 on tree, 156.823 best solution, best possible 126.59379 (144.23 seconds)
# Cbc0010I After 16900 nodes, 2028 on tree, 156.823 best solution, best possible 126.61417 (144.98 seconds)
# Cbc0010I After 17000 nodes, 2044 on tree, 156.823 best solution, best possible 126.62395 (145.40 seconds)
# Cbc0010I After 17100 nodes, 2044 on tree, 156.823 best solution, best possible 126.62395 (145.65 seconds)
# Cbc0010I After 17200 nodes, 2040 on tree, 156.823 best solution, best possible 126.62395 (145.92 seconds)
# Cbc0010I After 17300 nodes, 2042 on tree, 156.823 best solution, best possible 126.62395 (146.27 seconds)
# Cbc0010I After 17400 nodes, 2038 on tree, 156.823 best solution, best possible 126.62395 (146.67 seconds)
# Cbc0010I After 17500 nodes, 2038 on tree, 156.823 best solution, best possible 126.62395 (147.05 seconds)
# Cbc0010I After 17600 nodes, 2031 on tree, 156.823 best solution, best possible 126.62395 (147.41 seconds)
# Cbc0010I After 17700 nodes, 2026 on tree, 156.823 best solution, best possible 126.62395 (147.79 seconds)
# Cbc0010I After 17800 nodes, 2023 on tree, 156.823 best solution, best possible 126.62395 (148.07 seconds)
# Cbc0010I After 17900 nodes, 2023 on tree, 156.823 best solution, best possible 126.62395 (148.42 seconds)
# Cbc0010I After 18000 nodes, 2023 on tree, 156.823 best solution, best possible 126.62395 (148.78 seconds)
# Cbc0010I After 18100 nodes, 2043 on tree, 156.823 best solution, best possible 126.638 (149.50 seconds)
# Cbc0010I After 18200 nodes, 2071 on tree, 156.823 best solution, best possible 126.64799 (150.85 seconds)
# Cbc0010I After 18300 nodes, 2095 on tree, 156.823 best solution, best possible 126.67435 (151.56 seconds)
# Cbc0010I After 18400 nodes, 2110 on tree, 156.823 best solution, best possible 126.703 (152.21 seconds)
# Cbc0010I After 18500 nodes, 2136 on tree, 156.823 best solution, best possible 126.71333 (152.90 seconds)
# Cbc0010I After 18600 nodes, 2166 on tree, 156.823 best solution, best possible 126.71333 (153.99 seconds)
# Cbc0010I After 18700 nodes, 2198 on tree, 156.823 best solution, best possible 126.72333 (155.64 seconds)
# Cbc0010I After 18800 nodes, 2233 on tree, 156.823 best solution, best possible 126.72333 (156.04 seconds)
# Cbc0010I After 18900 nodes, 2263 on tree, 156.823 best solution, best possible 126.72333 (156.47 seconds)
# Cbc0010I After 19000 nodes, 2286 on tree, 156.823 best solution, best possible 126.735 (156.94 seconds)
# Cbc0010I After 19100 nodes, 2311 on tree, 156.823 best solution, best possible 126.75581 (157.41 seconds)
# Cbc0010I After 19200 nodes, 2335 on tree, 156.823 best solution, best possible 126.78003 (157.97 seconds)
# Cbc0010I After 19300 nodes, 2357 on tree, 156.823 best solution, best possible 126.79435 (158.58 seconds)
# Cbc0010I After 19400 nodes, 2376 on tree, 156.823 best solution, best possible 126.81324 (159.33 seconds)
# Cbc0010I After 19500 nodes, 2398 on tree, 156.823 best solution, best possible 126.83249 (160.01 seconds)
# Cbc0010I After 19600 nodes, 2409 on tree, 156.823 best solution, best possible 126.87386 (160.57 seconds)
# Cbc0010I After 19700 nodes, 2431 on tree, 156.823 best solution, best possible 126.90259 (161.33 seconds)
# Cbc0010I After 19800 nodes, 2454 on tree, 156.823 best solution, best possible 126.93833 (162.01 seconds)
# Cbc0010I After 19900 nodes, 2477 on tree, 156.823 best solution, best possible 126.97515 (162.51 seconds)
# Cbc0010I After 20000 nodes, 2489 on tree, 156.823 best solution, best possible 127.01 (163.18 seconds)
# Cbc0010I After 20100 nodes, 2510 on tree, 156.823 best solution, best possible 127.01 (163.87 seconds)
# Cbc0010I After 20200 nodes, 2530 on tree, 156.823 best solution, best possible 127.02769 (164.37 seconds)
# Cbc0010I After 20300 nodes, 2558 on tree, 156.823 best solution, best possible 127.04886 (164.95 seconds)
# Cbc0010I After 20400 nodes, 2584 on tree, 156.823 best solution, best possible 127.06724 (165.44 seconds)
# Cbc0010I After 20500 nodes, 2613 on tree, 156.823 best solution, best possible 127.08917 (165.88 seconds)
# Cbc0010I After 20600 nodes, 2633 on tree, 156.823 best solution, best possible 127.13741 (166.49 seconds)
# Cbc0010I After 20700 nodes, 2654 on tree, 156.823 best solution, best possible 127.1549 (167.09 seconds)
# Cbc0010I After 20800 nodes, 2669 on tree, 156.823 best solution, best possible 127.20079 (167.55 seconds)
# Cbc0010I After 20900 nodes, 2699 on tree, 156.823 best solution, best possible 127.22333 (168.02 seconds)
# Cbc0010I After 21000 nodes, 2725 on tree, 156.823 best solution, best possible 127.22333 (168.34 seconds)
# Cbc0012I Integer solution of 156.738 found by rounding after 2738676 iterations and 21052 nodes (168.59 seconds)
# Cbc0010I After 21100 nodes, 2726 on tree, 156.738 best solution, best possible 127.22333 (168.75 seconds)
# Cbc0010I After 21200 nodes, 2727 on tree, 156.738 best solution, best possible 127.22333 (169.12 seconds)
# Cbc0010I After 21300 nodes, 2733 on tree, 156.738 best solution, best possible 127.22333 (169.45 seconds)
# Cbc0010I After 21400 nodes, 2749 on tree, 156.738 best solution, best possible 127.22333 (169.91 seconds)
# Cbc0010I After 21500 nodes, 2761 on tree, 156.738 best solution, best possible 127.22333 (170.35 seconds)
# Cbc0010I After 21600 nodes, 2775 on tree, 156.738 best solution, best possible 127.22333 (170.81 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 604 rows 75 columns
# Cbc0010I After 21700 nodes, 2783 on tree, 156.738 best solution, best possible 127.22333 (171.15 seconds)
# Cbc0010I After 21800 nodes, 2795 on tree, 156.738 best solution, best possible 127.22333 (171.60 seconds)
# Cbc0010I After 21900 nodes, 2805 on tree, 156.738 best solution, best possible 127.22333 (172.16 seconds)
# Cbc0010I After 22000 nodes, 2808 on tree, 156.738 best solution, best possible 127.22333 (172.81 seconds)
# Cbc0010I After 22100 nodes, 2815 on tree, 156.738 best solution, best possible 127.25428 (173.42 seconds)
# Cbc0010I After 22200 nodes, 2835 on tree, 156.738 best solution, best possible 127.28829 (174.36 seconds)
# Cbc0010I After 22300 nodes, 2843 on tree, 156.738 best solution, best possible 127.34075 (174.94 seconds)
# Cbc0010I After 22400 nodes, 2859 on tree, 156.738 best solution, best possible 127.3889 (175.80 seconds)
# Cbc0010I After 22500 nodes, 2879 on tree, 156.738 best solution, best possible 127.45133 (176.48 seconds)
# Cbc0010I After 22600 nodes, 2903 on tree, 156.738 best solution, best possible 127.49995 (177.04 seconds)
# Cbc0010I After 22700 nodes, 2944 on tree, 156.738 best solution, best possible 127.49995 (177.87 seconds)
# Cbc0010I After 22800 nodes, 2974 on tree, 156.738 best solution, best possible 127.51 (178.58 seconds)
# Cbc0010I After 22900 nodes, 3000 on tree, 156.738 best solution, best possible 127.51 (179.03 seconds)
# Cbc0010I After 23000 nodes, 3030 on tree, 156.738 best solution, best possible 127.51 (179.55 seconds)
# Cbc0010I After 23100 nodes, 3057 on tree, 156.738 best solution, best possible 127.51 (180.22 seconds)
# Cbc0010I After 23200 nodes, 3082 on tree, 156.738 best solution, best possible 127.51 (180.70 seconds)
# Cbc0010I After 23300 nodes, 3102 on tree, 156.738 best solution, best possible 127.51338 (181.14 seconds)
# Cbc0010I After 23400 nodes, 3125 on tree, 156.738 best solution, best possible 127.53298 (181.62 seconds)
# Cbc0010I After 23500 nodes, 3148 on tree, 156.738 best solution, best possible 127.56549 (182.10 seconds)
# Cbc0010I After 23600 nodes, 3173 on tree, 156.738 best solution, best possible 127.59542 (182.57 seconds)
# Cbc0010I After 23700 nodes, 3193 on tree, 156.738 best solution, best possible 127.63307 (183.06 seconds)
# Cbc0010I After 23800 nodes, 3212 on tree, 156.738 best solution, best possible 127.64722 (183.55 seconds)
# Cbc0010I After 23900 nodes, 3228 on tree, 156.738 best solution, best possible 127.69272 (184.05 seconds)
# Cbc0010I After 24000 nodes, 3251 on tree, 156.738 best solution, best possible 127.71874 (184.60 seconds)
# Cbc0010I After 24100 nodes, 3286 on tree, 156.738 best solution, best possible 127.72333 (185.12 seconds)
# Cbc0010I After 24200 nodes, 3312 on tree, 156.738 best solution, best possible 127.72333 (185.61 seconds)
# Cbc0010I After 24300 nodes, 3338 on tree, 156.738 best solution, best possible 127.72333 (186.16 seconds)
# Cbc0010I After 24400 nodes, 3369 on tree, 156.738 best solution, best possible 127.72333 (186.65 seconds)
# Cbc0010I After 24500 nodes, 3394 on tree, 156.738 best solution, best possible 127.72418 (187.25 seconds)
# Cbc0010I After 24600 nodes, 3421 on tree, 156.738 best solution, best possible 127.74195 (187.76 seconds)
# Cbc0010I After 24700 nodes, 3442 on tree, 156.738 best solution, best possible 127.7531 (188.06 seconds)
# Cbc0010I After 24800 nodes, 3463 on tree, 156.738 best solution, best possible 127.77441 (188.46 seconds)
# Cbc0010I After 24900 nodes, 3497 on tree, 156.738 best solution, best possible 127.80275 (188.88 seconds)
# Cbc0010I After 25000 nodes, 3512 on tree, 156.738 best solution, best possible 127.82852 (189.27 seconds)
# Cbc0016I Integer solution of 147.154 found by strong branching after 3072622 iterations and 25006 nodes (189.30 seconds)
# Cbc0010I After 25100 nodes, 3184 on tree, 147.154 best solution, best possible 127.82852 (189.60 seconds)
# Cbc0010I After 25200 nodes, 3187 on tree, 147.154 best solution, best possible 127.82852 (189.98 seconds)
# Cbc0010I After 25300 nodes, 3202 on tree, 147.154 best solution, best possible 127.82852 (190.47 seconds)
# Cbc0010I After 25400 nodes, 3215 on tree, 147.154 best solution, best possible 127.82852 (191.00 seconds)
# Cbc0010I After 25500 nodes, 3224 on tree, 147.154 best solution, best possible 127.82852 (191.51 seconds)
# Cbc0010I After 25600 nodes, 3234 on tree, 147.154 best solution, best possible 127.82852 (191.94 seconds)
# Cbc0010I After 25700 nodes, 3249 on tree, 147.154 best solution, best possible 127.82852 (192.53 seconds)
# Cbc0010I After 25800 nodes, 3273 on tree, 147.154 best solution, best possible 127.82852 (193.10 seconds)
# Cbc0010I After 25900 nodes, 3279 on tree, 147.154 best solution, best possible 127.82852 (193.56 seconds)
# Cbc0010I After 26000 nodes, 3290 on tree, 147.154 best solution, best possible 127.82852 (194.02 seconds)
# Cbc0010I After 26100 nodes, 3309 on tree, 147.154 best solution, best possible 127.84955 (194.54 seconds)
# Cbc0010I After 26200 nodes, 3327 on tree, 147.154 best solution, best possible 127.88069 (195.12 seconds)
# Cbc0010I After 26300 nodes, 3341 on tree, 147.154 best solution, best possible 127.92489 (195.72 seconds)
# Cbc0010I After 26400 nodes, 3355 on tree, 147.154 best solution, best possible 127.97277 (196.41 seconds)
# Cbc0010I After 26500 nodes, 3385 on tree, 147.154 best solution, best possible 127.99995 (197.13 seconds)
# Cbc0010I After 26600 nodes, 3411 on tree, 147.154 best solution, best possible 128.0035 (197.89 seconds)
# Cbc0010I After 26700 nodes, 3427 on tree, 147.154 best solution, best possible 128.05464 (198.40 seconds)
# Cbc0010I After 26800 nodes, 3447 on tree, 147.154 best solution, best possible 128.09115 (199.09 seconds)
# Cbc0010I After 26900 nodes, 3465 on tree, 147.154 best solution, best possible 128.1496 (199.84 seconds)
# Cbc0010I After 27000 nodes, 3483 on tree, 147.154 best solution, best possible 128.19986 (200.38 seconds)
# Cbc0010I After 27100 nodes, 3499 on tree, 147.154 best solution, best possible 128.22333 (200.83 seconds)
# Cbc0010I After 27200 nodes, 3516 on tree, 147.154 best solution, best possible 128.27436 (201.47 seconds)
# Cbc0010I After 27300 nodes, 3532 on tree, 147.154 best solution, best possible 128.31964 (201.98 seconds)
# Cbc0010I After 27400 nodes, 3550 on tree, 147.154 best solution, best possible 128.35719 (202.48 seconds)
# Cbc0010I After 27500 nodes, 3561 on tree, 147.154 best solution, best possible 128.4149 (203.05 seconds)
# Cbc0010I After 27600 nodes, 3568 on tree, 147.154 best solution, best possible 128.45579 (203.61 seconds)
# Cbc0010I After 27700 nodes, 3582 on tree, 147.154 best solution, best possible 128.505 (204.44 seconds)
# Cbc0010I After 27800 nodes, 3612 on tree, 147.154 best solution, best possible 128.515 (205.08 seconds)
# Cbc0010I After 27900 nodes, 3635 on tree, 147.154 best solution, best possible 128.515 (205.52 seconds)
# Cbc0010I After 28000 nodes, 3657 on tree, 147.154 best solution, best possible 128.54003 (206.06 seconds)
# Cbc0010I After 28100 nodes, 3666 on tree, 147.154 best solution, best possible 128.58617 (206.51 seconds)
# Cbc0010I After 28200 nodes, 3681 on tree, 147.154 best solution, best possible 128.60935 (207.02 seconds)
# Cbc0010I After 28300 nodes, 3691 on tree, 147.154 best solution, best possible 128.67067 (207.76 seconds)
# Cbc0010I After 28400 nodes, 3716 on tree, 147.154 best solution, best possible 128.67881 (208.22 seconds)
# Cbc0010I After 28500 nodes, 3734 on tree, 147.154 best solution, best possible 128.71614 (208.69 seconds)
# Cbc0010I After 28600 nodes, 3750 on tree, 147.154 best solution, best possible 128.747 (209.02 seconds)
# Cbc0010I After 28700 nodes, 3781 on tree, 147.154 best solution, best possible 128.7882 (209.62 seconds)
# Cbc0010I After 28800 nodes, 3802 on tree, 147.154 best solution, best possible 128.82352 (209.90 seconds)
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 995 rows 89 columns - 4 fixed gives 898, 76 - ok now
# Cbc0038I Full problem 1795 rows 272 columns, reduced to 682 rows 76 columns
# Cbc0010I After 28900 nodes, 3821 on tree, 147.154 best solution, best possible 128.852 (210.38 seconds)
# Cbc0010I After 29000 nodes, 3834 on tree, 147.154 best solution, best possible 128.88281 (210.78 seconds)
# Cbc0010I After 29100 nodes, 3819 on tree, 147.154 best solution, best possible 128.88281 (210.98 seconds)
# Cbc0010I After 29200 nodes, 3802 on tree, 147.154 best solution, best possible 128.88281 (211.21 seconds)
# Cbc0010I After 29300 nodes, 3792 on tree, 147.154 best solution, best possible 128.88281 (211.46 seconds)
# Cbc0010I After 29400 nodes, 3786 on tree, 147.154 best solution, best possible 128.88281 (211.67 seconds)
# Cbc0010I After 29500 nodes, 3781 on tree, 147.154 best solution, best possible 128.88281 (211.90 seconds)
# Cbc0010I After 29600 nodes, 3780 on tree, 147.154 best solution, best possible 128.88281 (212.11 seconds)
# Cbc0010I After 29700 nodes, 3769 on tree, 147.154 best solution, best possible 128.88281 (212.37 seconds)
# Cbc0010I After 29800 nodes, 3761 on tree, 147.154 best solution, best possible 128.88281 (212.63 seconds)
# Cbc0010I After 29900 nodes, 3743 on tree, 147.154 best solution, best possible 128.88281 (212.94 seconds)
# Cbc0010I After 30000 nodes, 3730 on tree, 147.154 best solution, best possible 128.88281 (213.17 seconds)
# Cbc0010I After 30100 nodes, 3735 on tree, 147.154 best solution, best possible 128.92903 (213.72 seconds)
# Cbc0010I After 30200 nodes, 3741 on tree, 147.154 best solution, best possible 128.96078 (214.25 seconds)
# Cbc0010I After 30300 nodes, 3745 on tree, 147.154 best solution, best possible 129.00372 (214.79 seconds)
# Cbc0010I After 30400 nodes, 3746 on tree, 147.154 best solution, best possible 129.05694 (215.33 seconds)
# Cbc0010I After 30500 nodes, 3753 on tree, 147.154 best solution, best possible 129.12327 (215.94 seconds)
# Cbc0010I After 30600 nodes, 3763 on tree, 147.154 best solution, best possible 129.19842 (216.42 seconds)
# Cbc0010I After 30700 nodes, 3777 on tree, 147.154 best solution, best possible 129.25967 (216.89 seconds)
# Cbc0010I After 30800 nodes, 3785 on tree, 147.154 best solution, best possible 129.31173 (217.48 seconds)
# Cbc0010I After 30900 nodes, 3810 on tree, 147.154 best solution, best possible 129.38012 (217.95 seconds)
# Cbc0010I After 31000 nodes, 3819 on tree, 147.154 best solution, best possible 129.43545 (218.50 seconds)
# Cbc0010I After 31100 nodes, 3824 on tree, 147.154 best solution, best possible 129.51048 (219.06 seconds)
# Cbc0010I After 31200 nodes, 3827 on tree, 147.154 best solution, best possible 129.56926 (219.53 seconds)
# Cbc0010I After 31300 nodes, 3830 on tree, 147.154 best solution, best possible 129.6393 (220.18 seconds)
# Cbc0010I After 31400 nodes, 3828 on tree, 147.154 best solution, best possible 129.73219 (220.89 seconds)
# Cbc0010I After 31500 nodes, 3833 on tree, 147.154 best solution, best possible 129.79618 (221.38 seconds)
# Cbc0010I After 31600 nodes, 3843 on tree, 147.154 best solution, best possible 129.84157 (221.85 seconds)
# Cbc0010I After 31700 nodes, 3852 on tree, 147.154 best solution, best possible 129.89795 (222.44 seconds)
# Cbc0010I After 31800 nodes, 3867 on tree, 147.154 best solution, best possible 129.96675 (223.17 seconds)
# Cbc0010I After 31900 nodes, 3880 on tree, 147.154 best solution, best possible 130.00997 (223.81 seconds)
# Cbc0010I After 32000 nodes, 3894 on tree, 147.154 best solution, best possible 130.09319 (224.42 seconds)
# Cbc0010I After 32100 nodes, 3909 on tree, 147.154 best solution, best possible 130.16618 (224.88 seconds)
# Cbc0010I After 32200 nodes, 3926 on tree, 147.154 best solution, best possible 130.23656 (225.38 seconds)
# Cbc0010I After 32300 nodes, 3945 on tree, 147.154 best solution, best possible 130.31181 (225.88 seconds)
# Cbc0010I After 32400 nodes, 3952 on tree, 147.154 best solution, best possible 130.34708 (226.32 seconds)
# Cbc0010I After 32500 nodes, 3971 on tree, 147.154 best solution, best possible 130.38999 (227.03 seconds)
# Cbc0010I After 32600 nodes, 3999 on tree, 147.154 best solution, best possible 130.41894 (227.49 seconds)
# Cbc0010I After 32700 nodes, 4016 on tree, 147.154 best solution, best possible 130.46333 (227.97 seconds)
# Cbc0010I After 32800 nodes, 4015 on tree, 147.154 best solution, best possible 130.50995 (228.44 seconds)
# Cbc0010I After 32900 nodes, 4025 on tree, 147.154 best solution, best possible 130.54828 (228.96 seconds)
# Cbc0010I After 33000 nodes, 4033 on tree, 147.154 best solution, best possible 130.60489 (229.44 seconds)
# Cbc0010I After 33100 nodes, 4021 on tree, 147.154 best solution, best possible 130.60489 (229.64 seconds)
# Cbc0010I After 33200 nodes, 4011 on tree, 147.154 best solution, best possible 130.60489 (229.85 seconds)
# Cbc0010I After 33300 nodes, 4002 on tree, 147.154 best solution, best possible 130.60489 (230.13 seconds)
# Cbc0010I After 33400 nodes, 3995 on tree, 147.154 best solution, best possible 130.60489 (230.38 seconds)
# Cbc0010I After 33500 nodes, 3971 on tree, 147.154 best solution, best possible 130.60489 (230.69 seconds)
# Cbc0010I After 33600 nodes, 3949 on tree, 147.154 best solution, best possible 130.60489 (230.94 seconds)
# Cbc0010I After 33700 nodes, 3940 on tree, 147.154 best solution, best possible 130.60489 (231.26 seconds)
# Cbc0010I After 33800 nodes, 3924 on tree, 147.154 best solution, best possible 130.60489 (231.59 seconds)
# Cbc0010I After 33900 nodes, 3907 on tree, 147.154 best solution, best possible 130.60489 (232.05 seconds)
# Cbc0010I After 34000 nodes, 3903 on tree, 147.154 best solution, best possible 130.60489 (232.43 seconds)
# Cbc0010I After 34100 nodes, 3908 on tree, 147.154 best solution, best possible 130.65536 (233.08 seconds)
# Cbc0010I After 34200 nodes, 3927 on tree, 147.154 best solution, best possible 130.70989 (233.72 seconds)
# Cbc0010I After 34300 nodes, 3936 on tree, 147.154 best solution, best possible 130.72969 (234.27 seconds)
# ...
# Cbc0010I After 66600 nodes, 4181 on tree, 147.134 best solution, best possible 138.52199 (414.78 seconds)
# Cbc0010I After 66700 nodes, 4157 on tree, 147.134 best solution, best possible 138.55807 (415.38 seconds)
# Cbc0010I After 66800 nodes, 4133 on tree, 147.134 best solution, best possible 138.60809 (415.96 seconds)
# Cbc0010I After 66900 nodes, 4109 on tree, 147.134 best solution, best possible 138.64798 (416.58 seconds)
# Cbc0010I After 67000 nodes, 4080 on tree, 147.134 best solution, best possible 138.70991 (417.23 seconds)
# Cbc0010I After 67100 nodes, 4074 on tree, 147.134 best solution, best possible 138.73721 (418.13 seconds)
# Cbc0010I After 67200 nodes, 4055 on tree, 147.134 best solution, best possible 138.79584 (418.83 seconds)
# Cbc0010I After 67300 nodes, 4029 on tree, 147.134 best solution, best possible 138.8467 (419.64 seconds)
# Cbc0010I After 67400 nodes, 4024 on tree, 147.134 best solution, best possible 138.88992 (420.35 seconds)
# Cbc0010I After 67500 nodes, 4003 on tree, 147.134 best solution, best possible 138.93933 (421.06 seconds)
# Cbc0010I After 67600 nodes, 3979 on tree, 147.134 best solution, best possible 139.00151 (421.66 seconds)
# Cbc0010I After 67700 nodes, 3984 on tree, 147.134 best solution, best possible 139.02064 (422.94 seconds)
# Cbc0010I After 67800 nodes, 3969 on tree, 147.134 best solution, best possible 139.05998 (423.79 seconds)
# Cbc0010I After 67900 nodes, 3943 on tree, 147.134 best solution, best possible 139.10999 (424.28 seconds)
# Cbc0010I After 68000 nodes, 3917 on tree, 147.134 best solution, best possible 139.15858 (424.83 seconds)
# Cbc0010I After 68100 nodes, 3897 on tree, 147.134 best solution, best possible 139.20996 (425.42 seconds)
# Cbc0010I After 68200 nodes, 3866 on tree, 147.134 best solution, best possible 139.24829 (426.04 seconds)
# Cbc0010I After 68300 nodes, 3841 on tree, 147.134 best solution, best possible 139.30517 (426.64 seconds)
# Cbc0010I After 68400 nodes, 3817 on tree, 147.134 best solution, best possible 139.34562 (427.24 seconds)
# Cbc0010I After 68500 nodes, 3789 on tree, 147.134 best solution, best possible 139.41799 (427.87 seconds)
# Cbc0010I After 68600 nodes, 3767 on tree, 147.134 best solution, best possible 139.46959 (428.38 seconds)
# Cbc0010I After 68700 nodes, 3752 on tree, 147.134 best solution, best possible 139.50987 (429.15 seconds)
# Cbc0010I After 68800 nodes, 3740 on tree, 147.134 best solution, best possible 139.54569 (430.16 seconds)
# Cbc0010I After 68900 nodes, 3708 on tree, 147.134 best solution, best possible 139.60172 (430.71 seconds)
# Cbc0010I After 69000 nodes, 3673 on tree, 147.134 best solution, best possible 139.66514 (431.31 seconds)
# Cbc0010I After 69100 nodes, 3635 on tree, 147.134 best solution, best possible 139.66514 (431.69 seconds)
# Cbc0010I After 69200 nodes, 3603 on tree, 147.134 best solution, best possible 139.66514 (432.12 seconds)
# Cbc0010I After 69300 nodes, 3561 on tree, 147.134 best solution, best possible 139.66514 (432.47 seconds)
# Cbc0010I After 69400 nodes, 3537 on tree, 147.134 best solution, best possible 139.66514 (432.91 seconds)
# Cbc0010I After 69500 nodes, 3494 on tree, 147.134 best solution, best possible 139.66514 (433.39 seconds)
# Cbc0010I After 69600 nodes, 3449 on tree, 147.134 best solution, best possible 139.66514 (433.71 seconds)
# Cbc0010I After 69700 nodes, 3407 on tree, 147.134 best solution, best possible 139.66514 (434.08 seconds)
# Cbc0010I After 69800 nodes, 3373 on tree, 147.134 best solution, best possible 139.66514 (434.37 seconds)
# Cbc0010I After 69900 nodes, 3340 on tree, 147.134 best solution, best possible 139.66514 (434.78 seconds)
# Cbc0010I After 70000 nodes, 3303 on tree, 147.134 best solution, best possible 139.66514 (435.16 seconds)
# Cbc0010I After 70100 nodes, 3295 on tree, 147.134 best solution, best possible 139.71327 (436.26 seconds)
# Cbc0010I After 70200 nodes, 3262 on tree, 147.134 best solution, best possible 139.78234 (436.96 seconds)
# Cbc0010I After 70300 nodes, 3230 on tree, 147.134 best solution, best possible 139.84963 (437.71 seconds)
# Cbc0010I After 70400 nodes, 3204 on tree, 147.134 best solution, best possible 139.91699 (438.50 seconds)
# Cbc0010I After 70500 nodes, 3167 on tree, 147.134 best solution, best possible 139.97944 (439.12 seconds)
# Cbc0010I After 70600 nodes, 3129 on tree, 147.134 best solution, best possible 140.04479 (439.60 seconds)
# Cbc0010I After 70700 nodes, 3090 on tree, 147.134 best solution, best possible 140.13101 (440.01 seconds)
# Cbc0010I After 70800 nodes, 3053 on tree, 147.134 best solution, best possible 140.19911 (440.56 seconds)
# Cbc0010I After 70900 nodes, 3016 on tree, 147.134 best solution, best possible 140.27707 (441.11 seconds)
# Cbc0010I After 71000 nodes, 2981 on tree, 147.134 best solution, best possible 140.35324 (441.86 seconds)
# Cbc0010I After 71100 nodes, 2951 on tree, 147.134 best solution, best possible 140.44133 (442.43 seconds)
# Cbc0010I After 71200 nodes, 2918 on tree, 147.134 best solution, best possible 140.54004 (443.07 seconds)
# Cbc0010I After 71300 nodes, 2887 on tree, 147.134 best solution, best possible 140.64078 (443.58 seconds)
# Cbc0010I After 71400 nodes, 2858 on tree, 147.134 best solution, best possible 140.71387 (444.26 seconds)
# Cbc0010I After 71500 nodes, 2830 on tree, 147.134 best solution, best possible 140.78149 (444.94 seconds)
# Cbc0010I After 71600 nodes, 2790 on tree, 147.134 best solution, best possible 140.87543 (445.46 seconds)
# Cbc0010I After 71700 nodes, 2753 on tree, 147.134 best solution, best possible 140.95331 (446.09 seconds)
# Cbc0010I After 71800 nodes, 2719 on tree, 147.134 best solution, best possible 141.05706 (446.67 seconds)
# Cbc0010I After 71900 nodes, 2686 on tree, 147.134 best solution, best possible 141.15175 (447.15 seconds)
# Cbc0010I After 72000 nodes, 2651 on tree, 147.134 best solution, best possible 141.20826 (447.67 seconds)
# Cbc0010I After 72100 nodes, 2622 on tree, 147.134 best solution, best possible 141.30799 (448.21 seconds)
# Cbc0010I After 72200 nodes, 2583 on tree, 147.134 best solution, best possible 141.40076 (448.62 seconds)
# Cbc0010I After 72300 nodes, 2551 on tree, 147.134 best solution, best possible 141.47714 (449.39 seconds)
# Cbc0010I After 72400 nodes, 2515 on tree, 147.134 best solution, best possible 141.58572 (449.92 seconds)
# Cbc0010I After 72500 nodes, 2472 on tree, 147.134 best solution, best possible 141.68318 (450.41 seconds)
# Cbc0010I After 72600 nodes, 2440 on tree, 147.134 best solution, best possible 141.76629 (451.02 seconds)
# Cbc0010I After 72700 nodes, 2398 on tree, 147.134 best solution, best possible 141.88749 (451.54 seconds)
# Cbc0010I After 72800 nodes, 2360 on tree, 147.134 best solution, best possible 142.00729 (452.12 seconds)
# Cbc0010I After 72900 nodes, 2323 on tree, 147.134 best solution, best possible 142.12028 (452.65 seconds)
# Cbc0010I After 73000 nodes, 2292 on tree, 147.134 best solution, best possible 142.2118 (453.14 seconds)
# Cbc0010I After 73100 nodes, 2252 on tree, 147.134 best solution, best possible 142.2118 (453.55 seconds)
# Cbc0010I After 73200 nodes, 2214 on tree, 147.134 best solution, best possible 142.2118 (453.84 seconds)
# Cbc0010I After 73300 nodes, 2180 on tree, 147.134 best solution, best possible 142.2118 (454.23 seconds)
# Cbc0010I After 73400 nodes, 2147 on tree, 147.134 best solution, best possible 142.2118 (454.71 seconds)
# Cbc0010I After 73500 nodes, 2124 on tree, 147.134 best solution, best possible 142.2118 (455.39 seconds)
# Cbc0010I After 73600 nodes, 2086 on tree, 147.134 best solution, best possible 142.2118 (455.96 seconds)
# Cbc0010I After 73700 nodes, 2048 on tree, 147.134 best solution, best possible 142.2118 (456.31 seconds)
# Cbc0010I After 73800 nodes, 2006 on tree, 147.134 best solution, best possible 142.2118 (456.78 seconds)
# Cbc0010I After 73900 nodes, 1967 on tree, 147.134 best solution, best possible 142.2118 (457.27 seconds)
# Cbc0010I After 74000 nodes, 1922 on tree, 147.134 best solution, best possible 142.2118 (457.66 seconds)
# Cbc0010I After 74100 nodes, 1883 on tree, 147.134 best solution, best possible 142.33039 (458.23 seconds)
# Cbc0010I After 74200 nodes, 1847 on tree, 147.134 best solution, best possible 142.45198 (458.79 seconds)
# Cbc0010I After 74300 nodes, 1817 on tree, 147.134 best solution, best possible 142.53933 (459.67 seconds)
# Cbc0010I After 74400 nodes, 1783 on tree, 147.134 best solution, best possible 142.64772 (460.24 seconds)
# Cbc0010I After 74500 nodes, 1753 on tree, 147.134 best solution, best possible 142.73932 (460.84 seconds)
# Cbc0010I After 74600 nodes, 1711 on tree, 147.134 best solution, best possible 142.82287 (461.38 seconds)
# Cbc0010I After 74700 nodes, 1669 on tree, 147.134 best solution, best possible 142.95323 (461.81 seconds)
# Cbc0010I After 74800 nodes, 1652 on tree, 147.134 best solution, best possible 143.00999 (463.15 seconds)
# Cbc0010I After 74900 nodes, 1621 on tree, 147.134 best solution, best possible 143.07556 (463.67 seconds)
# Cbc0010I After 75000 nodes, 1582 on tree, 147.134 best solution, best possible 143.16837 (464.15 seconds)
# Cbc0010I After 75100 nodes, 1551 on tree, 147.134 best solution, best possible 143.2716 (465.31 seconds)
# Cbc0010I After 75200 nodes, 1522 on tree, 147.134 best solution, best possible 143.39093 (466.06 seconds)
# Cbc0010I After 75300 nodes, 1488 on tree, 147.134 best solution, best possible 143.50492 (467.09 seconds)
# Cbc0010I After 75400 nodes, 1451 on tree, 147.134 best solution, best possible 143.68958 (467.66 seconds)
# Cbc0010I After 75500 nodes, 1414 on tree, 147.134 best solution, best possible 143.81332 (468.22 seconds)
# Cbc0010I After 75600 nodes, 1368 on tree, 147.134 best solution, best possible 143.94681 (468.62 seconds)
# Cbc0010I After 75700 nodes, 1343 on tree, 147.134 best solution, best possible 144.02816 (469.95 seconds)
# Cbc0010I After 75800 nodes, 1314 on tree, 147.134 best solution, best possible 144.14874 (470.67 seconds)
# Cbc0010I After 75900 nodes, 1276 on tree, 147.134 best solution, best possible 144.29585 (471.22 seconds)
# Cbc0010I After 76000 nodes, 1239 on tree, 147.134 best solution, best possible 144.40994 (472.06 seconds)
# Cbc0010I After 76100 nodes, 1199 on tree, 147.134 best solution, best possible 144.57189 (472.57 seconds)
# Cbc0010I After 76200 nodes, 1157 on tree, 147.134 best solution, best possible 144.72349 (472.97 seconds)
# Cbc0010I After 76300 nodes, 1114 on tree, 147.134 best solution, best possible 144.86195 (473.25 seconds)
# Cbc0010I After 76400 nodes, 1073 on tree, 147.134 best solution, best possible 145.00492 (473.67 seconds)
# Cbc0010I After 76500 nodes, 1036 on tree, 147.134 best solution, best possible 145.09786 (474.57 seconds)
# Cbc0010I After 76600 nodes, 1001 on tree, 147.134 best solution, best possible 145.25625 (475.16 seconds)
# Cbc0010I After 76700 nodes, 958 on tree, 147.134 best solution, best possible 145.44333 (475.59 seconds)
# Cbc0010I After 76800 nodes, 917 on tree, 147.134 best solution, best possible 145.58781 (476.02 seconds)
# Cbc0010I After 76900 nodes, 874 on tree, 147.134 best solution, best possible 145.71332 (476.41 seconds)
# Cbc0010I After 77000 nodes, 826 on tree, 147.134 best solution, best possible 145.91152 (476.69 seconds)
# Cbc0010I After 77100 nodes, 803 on tree, 147.134 best solution, best possible 145.91152 (477.40 seconds)
# Cbc0010I After 77200 nodes, 766 on tree, 147.134 best solution, best possible 145.91152 (477.80 seconds)
# Cbc0010I After 77300 nodes, 729 on tree, 147.134 best solution, best possible 145.91152 (478.16 seconds)
# Cbc0010I After 77400 nodes, 720 on tree, 147.134 best solution, best possible 145.91152 (479.02 seconds)
# Cbc0010I After 77500 nodes, 686 on tree, 147.134 best solution, best possible 145.91152 (479.46 seconds)
# Cbc0010I After 77600 nodes, 650 on tree, 147.134 best solution, best possible 145.91152 (479.89 seconds)
# Cbc0010I After 77700 nodes, 633 on tree, 147.134 best solution, best possible 145.91152 (480.55 seconds)
# Cbc0010I After 77800 nodes, 601 on tree, 147.134 best solution, best possible 145.91152 (480.95 seconds)
# Cbc0010I After 77900 nodes, 572 on tree, 147.134 best solution, best possible 145.91152 (481.42 seconds)
# Cbc0010I After 78000 nodes, 527 on tree, 147.134 best solution, best possible 145.91152 (481.96 seconds)
# Cbc0010I After 78100 nodes, 512 on tree, 147.134 best solution, best possible 146.01 (482.93 seconds)
# Cbc0010I After 78200 nodes, 502 on tree, 147.134 best solution, best possible 146.08917 (483.88 seconds)
# Cbc0010I After 78300 nodes, 493 on tree, 147.134 best solution, best possible 146.176 (484.48 seconds)
# Cbc0010I After 78400 nodes, 491 on tree, 147.134 best solution, best possible 146.22333 (485.68 seconds)
# Cbc0010I After 78500 nodes, 473 on tree, 147.134 best solution, best possible 146.32196 (486.38 seconds)
# Cbc0010I After 78600 nodes, 456 on tree, 147.134 best solution, best possible 146.46096 (486.99 seconds)
# Cbc0010I After 78700 nodes, 436 on tree, 147.134 best solution, best possible 146.51 (487.60 seconds)
# Cbc0010I After 78800 nodes, 411 on tree, 147.134 best solution, best possible 146.57993 (488.29 seconds)
# Cbc0010I After 78900 nodes, 371 on tree, 147.134 best solution, best possible 146.648 (488.72 seconds)
# Cbc0010I After 79000 nodes, 339 on tree, 147.134 best solution, best possible 146.71333 (489.50 seconds)
# Cbc0010I After 79100 nodes, 306 on tree, 147.134 best solution, best possible 146.72929 (490.11 seconds)
# Cbc0010I After 79200 nodes, 269 on tree, 147.134 best solution, best possible 146.81247 (490.68 seconds)
# Cbc0010I After 79300 nodes, 220 on tree, 147.134 best solution, best possible 146.88233 (491.05 seconds)
# Cbc0010I After 79400 nodes, 173 on tree, 147.134 best solution, best possible 146.99995 (491.36 seconds)
# Cbc0010I After 79500 nodes, 146 on tree, 147.134 best solution, best possible 147.00985 (491.91 seconds)
# Cbc0010I After 79600 nodes, 126 on tree, 147.134 best solution, best possible 147.01 (492.75 seconds)
# Cbc0010I After 79700 nodes, 98 on tree, 147.134 best solution, best possible 147.01 (493.37 seconds)
# Cbc0010I After 79800 nodes, 73 on tree, 147.134 best solution, best possible 147.015 (494.07 seconds)
# Cbc0010I After 79900 nodes, 39 on tree, 147.134 best solution, best possible 147.05557 (494.71 seconds)
# Cbc0001I Search completed - best objective 147.134, took 6953736 iterations and 79979 nodes (494.94 seconds)
# Cbc0032I Strong branching done 208454 times (5458481 iterations), fathomed 10098 nodes and fixed 32829 variables
# Cbc0035I Maximum depth 64, 115988 variables fixed on reduced cost
# Cuts at root node changed objective from 46.5 to 122
# Probing was tried 100 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.326 seconds)
# Gomory was tried 63116 times and created 33110 cuts of which 0 were active after adding rounds of cuts (20.429 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.060 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 100 times and created 21 cuts of which 0 were active after adding rounds of cuts (0.119 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.153 seconds)
# TwoMirCuts was tried 63116 times and created 3556 cuts of which 0 were active after adding rounds of cuts (34.679 seconds)
# ZeroHalf was tried 100 times and created 31 cuts of which 0 were active after adding rounds of cuts (0.059 seconds)
#
# Result - Optimal solution found
#
# Objective value:                147.13400000
# Enumerated nodes:               79979
# Total iterations:               6953736
# Time (CPU seconds):             494.95
# Time (Wallclock seconds):       494.95
#
# Total time (CPU seconds):       495.03   (Wallclock seconds):       495.03
#
# Resultados da rodada:  i11_Simulado_cbc_20250128180605 Para o solver cbc
# Incumbent Solution: 147.134
# Solver Status: ok
# Solver Time: 495.2389271259308 seconds

# %% [markdown]
# # Exportação

# %%
elapsed_time_minutes = Func_ConversaoDatetimeParaMinutosParametros(elapsed_time)
print(elapsed_time_minutes)
# Out:
# {'i11': datetime.timedelta(seconds=495, microseconds=333732)}

# %%
# Exportação
df_export = pd.DataFrame({"P_SOL_NomeDaRodada": Ps_NomeDaRodada,
                            "P_SOL_incumbent_solution": P_SOL_incumbent_solution, 
                          "P_SOL_solver_status": P_SOL_solver_status, 
                          "P_SOL_solver_time": P_SOL_solver_time,
                          "elapsed_time_minutes" : elapsed_time_minutes,
                          "P_SOL_best_bound": P_SOL_best_bound,
                          "P_SOL_optimality_gap": P_SOL_optimality_gap,
                          "P_total_variables" : P_total_variables,
                          "P_integer_variables" : P_integer_variables,
                          "P_binary_variables": P_binary_variables,
                          "P_total_constraints" : P_total_constraints
                          })
print(df_export)

for i in S_VoosReais:
    for p in S_Posicoes:
        for h in S_Aeronaves:
            if V_X3[i,p,h].value > 0:
                print(f"V_X3({i},{p},{h}) = ", V_X3[i,p,h].value)

for i in S_VoosReais:
  if V_DT[i].value > 0:
      print(f"V_DT({i}) = ", V_DT[i].value)

# Penalidades FO
P_SOL_CancelamentoComitiva = P_PenCancelamentoComitiva * (len(S_VoosComitiva) - sum(V_X3[vooC,p,h].value for vooC in S_VoosComitiva for p in S_Posicoes for h in S_Aeronaves))
P_SOL_PenCancelamento2Dias = P_PenCancelamento2Dias * (len(S_VoosT2) - sum(V_X3[vooT2,p,h].value for vooT2 in S_VoosT2 for p in S_Posicoes for h in S_Aeronaves))
P_SOL_PenCancelamento1Dia =        P_PenCancelamento1Dia * (len(S_VoosT1) - sum(V_X3[vooT1,p,h].value for vooT1 in S_VoosT1 for p in S_Posicoes for h in S_Aeronaves))
P_SOL_PenCancelamentoTabela =        P_PenCancelamentoTabela * (len(S_VoosTabela) - sum(V_X3[vooTab,p,h].value for vooTab in S_VoosTabela for p in S_Posicoes for h in S_Aeronaves))
P_SOL_PenUsoAeronaveSpot    =  P_PenUsoAeronaveSpot * sum(V_X3[voo,S_Posicoes.at(1),hSpot].value for voo in S_VoosReais for hSpot in S_AeronavesSpot)
P_SOL_PenUsoAeronavePool    =  P_PenUsoAeronavePool * sum(V_X3[voo,S_Posicoes.at(1),hPool].value for voo in S_VoosReais for hPool in S_AeronavesPool)
P_SOL_PenUsoAeronaveComum   = P_PenUsoAeronaveComum * sum(V_X3[voo,S_Posicoes.at(1),hComum].value for voo in S_VoosReais for hComum in S_AeronavesComum)
P_SOL_PenAtrasoTipo2 =  P_PenAtrasoTipo2 * sum(V_BII[vooTabelaComitiva].value for vooTabelaComitiva in S_VoosTabelaComitiva)
P_SOL_PenAtrasoTipo1 =  P_PenAtrasoTipo1 * sum(V_BI[vooTabelaComitiva].value for vooTabelaComitiva in S_VoosTabelaComitiva)
P_SOL_PenAtrasoMinuto = P_PenAtrasoMinuto * sum(V_D[vooTodos].value for vooTodos in S_VoosReais)
P_SOL_PenTrocaAeronave = P_PenTrocaAeronave * sum(V_X3[vooTabelaComitiva,p,h].value * (1 - P_AeronaveInicial[vooTabelaComitiva,h]) for vooTabelaComitiva in S_VoosTabelaComitiva for p in S_Posicoes for h in S_Aeronaves)

P_NumeroDeVoos2 = len(S_VoosTabela)
P_SomatorioDeVoosAlocados = sum(V_X3[vooTab,p,h].value for vooTab in S_VoosTabela for p in S_Posicoes for h in S_Aeronaves)

print('P_NumeroDeVoos2 = ', P_NumeroDeVoos2)
print('P_SomatorioDeVoosAlocados = ', P_SomatorioDeVoosAlocados)
print('P_SOL_CancelamentoComitiva = ', P_SOL_CancelamentoComitiva)
print('P_SOL_PenCancelamento2Dias = ', P_SOL_PenCancelamento2Dias)
print('P_SOL_PenCancelamento1Dia = ', P_SOL_PenCancelamento1Dia)
print('P_SOL_PenCancelamentoTabela = ', P_SOL_PenCancelamentoTabela)
print('P_SOL_PenUsoAeronaveSpot = ', P_SOL_PenUsoAeronaveSpot)
print('P_SOL_PenUsoAeronavePool = ', P_SOL_PenUsoAeronavePool)
print('P_SOL_PenUsoAeronaveComum = ', P_SOL_PenUsoAeronaveComum)
print('P_SOL_PenAtrasoTipo2 = ', P_SOL_PenAtrasoTipo2)
print('P_SOL_PenAtrasoTipo1 = ', P_SOL_PenAtrasoTipo1)
print('P_SOL_PenAtrasoMinuto = ', P_SOL_PenAtrasoMinuto)
print('P_SOL_PenTrocaAeronave = ', P_SOL_PenTrocaAeronave)
#df_export.to_excel(f"DataFram_{Ps_NomeDaRodada}.xlsx", index = True)
#df_export.to_excel(f"G:\Meu Drive\Planilhas para Estudos\ResultadosPyomoM3\MIP_{solver_selecionado}_{P_HoraDaRodadaTimeStamp}.xlsx", index = True)7#
# Out:
#                   P_SOL_NomeDaRodada  P_SOL_incumbent_solution  \
# i11  i11_Simulado_cbc_20250128180605                   147.134
#
#     P_SOL_solver_status  P_SOL_solver_time   elapsed_time_minutes  \
# i11                  ok         495.238927 0 days 00:08:15.333732
#
#     P_SOL_best_bound P_SOL_optimality_gap  P_total_variables  \
# i11             None                 None                341
#
#      P_integer_variables  P_binary_variables  P_total_constraints
# i11                    0                 308                 2071
# V_X3(1,1,PR-SHL) =  1.0
# V_X3(2,2,PR-LCR) =  1.0
# V_X3(4,3,PR-LDG) =  1.0
# V_X3(5,1,PR-LCR) =  1.0
# V_X3(6,1,PR-LDG) =  1.0
# V_X3(7,2,PR-SHL) =  1.0
# V_X3(8,4,PR-LCR) =  1.0
# V_X3(9,2,PR-LDG) =  1.0
# V_X3(10,3,PR-SHL) =  1.0
# V_X3(11,3,PR-LCR) =  1.0
# V_DT(1) =  420.0
# V_DT(2) =  549.0
# V_DT(4) =  900.0
# V_DT(5) =  425.0
# V_DT(6) =  530.0
# V_DT(7) =  750.0
# V_DT(8) =  870.0
# V_DT(9) =  780.0
# V_DT(10) =  930.0
# V_DT(11) =  720.0
# P_NumeroDeVoos2 =  8
# P_SomatorioDeVoosAlocados =  7.0
# P_SOL_CancelamentoComitiva =  0
# P_SOL_PenCancelamento2Dias =  0.0
# P_SOL_PenCancelamento1Dia =  0.0
# P_SOL_PenCancelamentoTabela =  80.0
# P_SOL_PenUsoAeronaveSpot =  0
# P_SOL_PenUsoAeronavePool =  25.0
# P_SOL_PenUsoAeronaveComum =  40.0
# P_SOL_PenAtrasoTipo2 =  0.0
# P_SOL_PenAtrasoTipo1 =  0.0
# P_SOL_PenAtrasoMinuto =  0.134
# P_SOL_PenTrocaAeronave =  2.0

# %%
print(list(S_VoosTabela))
model.write('cbc.lp')
# Out:
# [1, 3, 4, 6, 7, 8, 9, 10]
# ('cbc.lp', 1750557934608)
